# %% [markdown]
# # 공정 데이터 생성

# %%
import numpy as np
import pandas as pd
import time
from time import sleep

# %%
def process():
    item_data = []
    std = 0.0025
    amount = 10
    
    ############################################################################
    
    op10_process_time = np.random.exponential(10, amount)
    op10_process_time = op10_process_time.round(5)
    
    op20_process_time = np.random.exponential(10, amount)
    op20_process_time = op20_process_time.round(5)
    
    op30_process_time = np.random.exponential(10, amount)
    op30_process_time = op30_process_time.round(5)
    
    op40_process_time = np.random.exponential(10, amount)
    op40_process_time = op40_process_time.round(5)
    
    op50_process_time = np.random.exponential(10, amount)
    op50_process_time = op50_process_time.round(5)
    
    ############################################################################
    
    body_l = np.random.normal(200,std, amount)
    body_l = body_l.round(5)
    body_w = np.random.normal(100,std, amount)
    body_w = body_w.round(5)
    body_h = np.random.normal(50,std, amount)
    body_h = body_h.round(5)
    
    wavyfin_l = np.random.normal(100,std, amount)
    wavyfin_l = wavyfin_l.round(5)
    wavyfin_w = np.random.normal(50,std, amount)
    wavyfin_w = wavyfin_w.round(5)
    wavyfin_h = np.random.normal(60,std, amount)
    wavyfin_h = wavyfin_h.round(5)
    
    op10_electricity = np.random.uniform(89, 100, amount)
    op10_electricity = op10_electricity.round(5)
    
    op10_l = body_l
    op10_w = body_w
    op10_h = wavyfin_h
    
    op10_test = []
    
    for test in range(amount):
    
        if (op10_l[test] < 199.99) or (op10_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op10_w[test] < 99.99) or (op10_w[test] > 100.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op10_h[test] < 59.99) or (op10_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op10_test.append(0)
        else:
            op10_test.append(1)
    
    ############################################################################
    
    pipe1_l = np.random.normal(30,std, amount)
    pipe1_l = pipe1_l.round(5)
    pipe1_w = np.random.normal(50,std, amount)
    pipe1_w = pipe1_w.round(5)
    pipe1_h = np.random.normal(30,std, amount)
    pipe1_h = pipe1_h.round(5)
    
    op20_electricity = np.random.uniform(89, 100, amount)
    op20_electricity = op20_electricity.round(5)
    
    op20_l = op10_l
    op20_w = body_w
    
    for item_20 in range(amount):
        
        if op20_electricity[item_20] < 90:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - op20_electricity[item_20] * 0.11
        else:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - 10
            
    op20_h = op10_h
    
    op20_test = []
    
    for test in range(amount):
    
        if (op20_l[test] < 199.99) or (op20_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op20_w[test] < 139.99) or (op20_w[test] > 140.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op20_h[test] < 59.99) or (op20_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op20_test.append(0)
        else:
            op20_test.append(1)
    
    ############################################################################
    
    pipe2_l = np.random.normal(30,std, amount)
    pipe2_l = pipe2_l.round(5)
    pipe2_w = np.random.normal(50,std, amount)
    pipe2_w = pipe2_w.round(5)
    pipe2_h = np.random.normal(30,std, amount)
    pipe2_h = pipe2_h.round(5)
    
    op30_electricity = np.random.uniform(89, 100, amount)
    op30_electricity = op30_electricity.round(5)
    
    op30_l = op20_l
    op30_w = op20_w
    
    for item_30 in range(amount):
        
        if op30_electricity[item_30] < 90:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - op30_electricity[item_30] * 0.11
        else:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - 10
            
    op30_h = op20_h
    
    op30_test = []
    
    for test in range(amount):
    
        if (op30_l[test] < 199.99) or (op30_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op30_w[test] < 179.99) or (op30_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op30_h[test] < 59.99) or (op30_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op30_test.append(0)
        else:
            op30_test.append(1)
    
    ############################################################################
    
    flange1_l = np.random.normal(30,std, amount)
    flange1_l = flange1_l.round(5)
    flange1_w = np.random.normal(80,std, amount)
    flange1_w = flange1_w.round(5)
    flange1_h = np.random.normal(40,std, amount)
    flange1_h = flange1_h.round(5)
    
    op40_temperature = np.random.uniform(489, 511, amount)
    op40_temperature = op40_temperature.round(5)
    
    op40_l = op30_l
    
    for item_40 in range(amount):
        
        if 489 < op40_temperature[item_40] < 511:
            op40_l[item_40] = op30_l[item_40] + flange1_l[item_40]
        else:
            op40_l[item_40] = 0
            
    op40_w = op30_w
    op40_h = op30_h
    
    op40_test = []
    
    for test in range(amount):
    
        if (op40_l[test] < 229.99) or (op40_l[test] > 230.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op40_w[test] < 179.99) or (op40_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op40_h[test] < 59.99) or (op40_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op40_test.append(0)
        else:
            op40_test.append(1)
    
    ############################################################################
    
    flange2_l = np.random.normal(30,std, amount)
    flange2_l = flange2_l.round(5)
    flange2_w = np.random.normal(80,std, amount)
    flange2_w = flange2_w.round(5)
    flange2_h = np.random.normal(40,std, amount)
    flange2_h = flange2_h.round(5)
    
    op50_temperature = np.random.uniform(489, 511, amount)
    op50_temperature = op50_temperature.round(5)
    
    op50_l = op40_l
    
    for item_50 in range(amount):
        
        if 489 < op50_temperature[item_50] < 511:
            op50_l[item_50] = op40_l[item_50] + flange2_l[item_50]
        else:
            op50_l[item_50] = 0
            
    op50_w = op40_w
    op50_h = op40_h
    
    ############################################################################
    
    op60_test = []
    
    for test in range(amount):
    
        if (op50_l[test] < 259.99) or (op50_l[test] > 260.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op50_w[test] < 179.99) or (op50_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op50_h[test] < 59.99) or (op50_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op60_test.append(0)
        else:
            op60_test.append(1)
            
        
    
    ############################################################################
    
    for i in range(amount):
        item = {}
        item['item_key'] = i
        item['body_l'] = body_l[i]
        item['body_w'] = body_w[i]
        item['body_h'] = body_h[i]
        
        item['wavyfin_l'] = wavyfin_l[i]
        item['wavyfin_w'] = wavyfin_w[i]
        item['wavyfin_h'] = wavyfin_h[i]
        
        item['op10_l'] = body_l[i]
        item['op10_w'] = body_w[i]
        item['op10_h'] = wavyfin_h[i]
        item['op10_electricity'] = op10_electricity[i]
        item['op10_process_time'] = op10_process_time[i]
        item['op10_test'] = op10_test[i]

        item['pipe1_l'] = pipe1_l[i]
        item['pipe1_w'] = pipe1_w[i]
        item['pipe1_h'] = pipe1_h[i]
        
        item['op20_l'] = op20_l[i]            
        item['op20_w'] = op20_w[i]
        item['op20_h'] = op20_h[i]
        item['op20_electricity'] = op20_electricity[i]
        item['op20_process_time'] = op20_process_time[i]
        item['op20_test'] = op20_test[i]
        
        item['pipe2_l'] = pipe2_l[i]
        item['pipe2_w'] = pipe2_w[i]
        item['pipe2_h'] = pipe2_h[i]
        
        item['op30_l'] = op30_l[i]            
        item['op30_w'] = op30_w[i]
        item['op30_h'] = op30_h[i]
        item['op30_electricity'] = op30_electricity[i]
        item['op30_process_time'] = op30_process_time[i]
        item['op30_test'] = op30_test[i]
        
        item['flange1_l'] = flange1_l[i]
        item['flange1_w'] = flange1_w[i]
        item['flange1_h'] = flange1_h[i]
        
        item['op40_l'] = op40_l[i]            
        item['op40_w'] = op40_w[i]
        item['op40_h'] = op40_h[i]
        item['op40_temperature'] = op40_temperature[i]
        item['op40_process_time'] = op40_process_time[i]
        item['op40_test'] = op40_test[i]
        
        item['flange2_l'] = flange2_l[i]
        item['flange2_w'] = flange2_w[i]
        item['flange2_h'] = flange2_h[i]
        
        item['op50_l'] = op50_l[i]            
        item['op50_w'] = op50_w[i]
        item['op50_h'] = op50_h[i]
        item['op50_temperature'] = op50_temperature[i]
        item['op50_process_time'] = op50_process_time[i]
        
        item['op60_test'] = op60_test[i]
        
        item_data.append(item)
    
    return item_data

# %%
process()
# Out:
# [{'item_key': 0,
#   'body_l': 259.9937,
#   'body_w': 179.99288,
#   'body_h': 50.00236,
#   'wavyfin_l': 99.99852,
#   'wavyfin_w': 49.9962,
#   'wavyfin_h': 59.99831,
#   'op10_l': 259.9937,
#   'op10_w': 179.99288,
#   'op10_h': 59.99831,
#   'op10_electricity': 94.57248,
#   'op10_process_time': 0.80147,
#   'op10_test': 0,
#   'pipe1_l': 30.00024,
#   'pipe1_w': 49.99835,
#   'pipe1_h': 29.99724,
#   'op20_l': 259.9937,
#   'op20_w': 179.99288,
#   'op20_h': 59.99831,
#   'op20_electricity': 94.55082,
#   'op20_process_time': 0.06225,
#   'op20_test': 0,
#   'pipe2_l': 30.00051,
#   'pipe2_w': 49.99721,
#   'pipe2_h': 30.00002,
#   'op30_l': 259.9937,
#   'op30_w': 179.99288,
#   'op30_h': 59.99831,
#   'op30_electricity': 91.28507,
#   'op30_process_time': 6.31728,
#   'op30_test': 0,
#   'flange1_l': 29.99727,
#   'flange1_w': 79.99852,
#   'flange1_h': 40.0004,
#   'op40_l': 259.9937,
#   'op40_w': 179.99288,
#   'op40_h': 59.99831,
#   'op40_temperature': 504.49766,
#   'op40_process_time': 5.0396,
#   'op40_test': 0,
#   'flange2_l': 29.99679,
#   'flange2_w': 80.00043,
#   'flange2_h': 40.001,
#   'op50_l': 259.9937,
#   'op50_w': 179.99288,
#   'op50_h': 59.99831,
#   'op50_temperature': 492.28735,
#   'op50_process_time': 1.04365,
#   'op60_test': 0},
#  {'item_key': 1,
#   'body_l': 259.99844,
#   'body_w': 180.00309000000001,
#   'body_h': 50.00134,
#   'wavyfin_l': 99.99572,
#   'wavyfin_w': 49.99641,
#   'wavyfin_h': 59.99871,
#   'op10_l': 259.99844,
#   'op10_w': 180.00309000000001,
#   'op10_h': 59.99871,
#   'op10_electricity': 91.86332,
#   'op10_process_time': 6.07422,
#   'op10_test': 0,
#   'pipe1_l': 29.99849,
#   'pipe1_w': 50.00004,
#   'pipe1_h': 29.99918,
#   'op20_l': 259.99844,
#   'op20_w': 180.00309000000001,
#   'op20_h': 59.99871,
#   'op20_electricity': 94.0666,
#   'op20_process_time': 7.0753,
#   'op20_test': 0,
#   'pipe2_l': 30.00128,
#   'pipe2_w': 49.99992,
#   'pipe2_h': 29.99808,
#   'op30_l': 259.99844,
#   'op30_w': 180.00309000000001,
#   'op30_h': 59.99871,
#   'op30_electricity': 90.84902,
#   'op30_process_time': 8.30779,
#   'op30_test': 0,
#   'flange1_l': 29.99751,
#   'flange1_w': 79.99946,
#   'flange1_h': 40.00105,
#   'op40_l': 259.99844,
#   'op40_w': 180.00309000000001,
#   'op40_h': 59.99871,
#   'op40_temperature': 500.69556,
#   'op40_process_time': 32.74411,
#   'op40_test': 0,
#   'flange2_l': 30.00208,
#   'flange2_w': 80.00073,
#   'flange2_h': 39.99802,
#   'op50_l': 259.99844,
#   'op50_w': 180.00309000000001,
#   'op50_h': 59.99871,
#   'op50_temperature': 509.23031,
#   'op50_process_time': 0.21712,
#   'op60_test': 0},
#  {'item_key': 2,
#   'body_l': 259.99528,
#   'body_w': 180.00910000000002,
#   'body_h': 49.99975,
#   'wavyfin_l': 99.99952,
#   'wavyfin_w': 49.99857,
#   'wavyfin_h': 59.99847,
#   'op10_l': 259.99528,
#   'op10_w': 180.00910000000002,
#   'op10_h': 59.99847,
#   'op10_electricity': 90.53194,
#   'op10_process_time': 1.37994,
#   'op10_test': 0,
#   'pipe1_l': 30.00216,
#   'pipe1_w': 50.00631,
#   'pipe1_h': 29.99868,
#   'op20_l': 259.99528,
#   'op20_w': 180.00910000000002,
#   'op20_h': 59.99847,
#   'op20_electricity': 97.02243,
#   'op20_process_time': 14.67982,
#   'op20_test': 0,
#   'pipe2_l': 29.99678,
#   'pipe2_w': 49.99884,
#   'pipe2_h': 30.00034,
#   'op30_l': 259.99528,
#   'op30_w': 180.00910000000002,
#   'op30_h': 59.99847,
#   'op30_electricity': 93.52094,
#   'op30_process_time': 24.64332,
#   'op30_test': 0,
#   'flange1_l': 30.00149,
#   'flange1_w': 79.99771,
#   'flange1_h': 39.99883,
#   'op40_l': 259.99528,
#   'op40_w': 180.00910000000002,
#   'op40_h': 59.99847,
#   'op40_temperature': 502.8456,
#   'op40_process_time': 0.70692,
#   'op40_test': 0,
#   'flange2_l': 29.99543,
#   'flange2_w': 80.00172,
#   'flange2_h': 39.99654,
#   'op50_l': 259.99528,
#   'op50_w': 180.00910000000002,
#   'op50_h': 59.99847,
#   'op50_temperature': 492.83716,
#   'op50_process_time': 4.51297,
#   'op60_test': 0},
#  {'item_key': 3,
#   'body_l': 259.99377,
#   'body_w': 180.00036,
#   'body_h': 49.99489,
#   'wavyfin_l': 99.99606,
#   'wavyfin_w': 50.00033,
#   'wavyfin_h': 59.9989,
#   'op10_l': 259.99377,
#   'op10_w': 180.00036,
#   'op10_h': 59.9989,
#   'op10_electricity': 98.90332,
#   'op10_process_time': 0.00997,
#   'op10_test': 0,
#   'pipe1_l': 30.00232,
#   'pipe1_w': 50.00042,
#   'pipe1_h': 30.00065,
#   'op20_l': 259.99377,
#   'op20_w': 180.00036,
#   'op20_h': 59.9989,
#   'op20_electricity': 95.24547,
#   'op20_process_time': 11.74933,
#   'op20_test': 0,
#   'pipe2_l': 30.00086,
#   'pipe2_w': 50.00029,
#   'pipe2_h': 29.99952,
#   'op30_l': 259.99377,
#   'op30_w': 180.00036,
#   'op30_h': 59.9989,
#   'op30_electricity': 99.2383,
#   'op30_process_time': 7.32652,
#   'op30_test': 0,
#   'flange1_l': 30.00006,
#   'flange1_w': 80.00142,
#   'flange1_h': 39.99675,
#   'op40_l': 259.99377,
#   'op40_w': 180.00036,
#   'op40_h': 59.9989,
#   'op40_temperature': 498.53382,
#   'op40_process_time': 28.93407,
#   'op40_test': 0,
#   'flange2_l': 30.00068,
#   'flange2_w': 80.00343,
#   'flange2_h': 40.00616,
#   'op50_l': 259.99377,
#   'op50_w': 180.00036,
#   'op50_h': 59.9989,
#   'op50_temperature': 497.37846,
#   'op50_process_time': 0.83602,
#   'op60_test': 0},
#  {'item_key': 4,
#   'body_l': 260.00025,
#   'body_w': 180.00462000000002,
#   'body_h': 50.00074,
#   'wavyfin_l': 99.99804,
#   'wavyfin_w': 50.00164,
#   'wavyfin_h': 60.00188,
#   'op10_l': 260.00025,
#   'op10_w': 180.00462000000002,
#   'op10_h': 60.00188,
#   'op10_electricity': 92.3148,
#   'op10_process_time': 3.45861,
#   'op10_test': 0,
#   'pipe1_l': 29.9979,
#   'pipe1_w': 50.00299,
#   'pipe1_h': 30.00245,
#   'op20_l': 260.00025,
#   'op20_w': 180.00462000000002,
#   'op20_h': 60.00188,
#   'op20_electricity': 90.72242,
#   'op20_process_time': 15.42194,
#   'op20_test': 0,
#   'pipe2_l': 30.00146,
#   'pipe2_w': 50.001,
#   'pipe2_h': 29.99932,
#   'op30_l': 260.00025,
#   'op30_w': 180.00462000000002,
#   'op30_h': 60.00188,
#   'op30_electricity': 94.88638,
#   'op30_process_time': 1.47437,
#   'op30_test': 0,
#   'flange1_l': 29.99996,
#   'flange1_w': 79.99822,
#   'flange1_h': 40.00241,
#   'op40_l': 260.00025,
#   'op40_w': 180.00462000000002,
#   'op40_h': 60.00188,
#   'op40_temperature': 494.1299,
#   'op40_process_time': 5.68275,
#   'op40_test': 0,
#   'flange2_l': 29.99929,
#   'flange2_w': 79.99792,
#   'flange2_h': 39.99988,
#   'op50_l': 260.00025,
#   'op50_w': 180.00462000000002,
#   'op50_h': 60.00188,
#   'op50_temperature': 489.23727,
#   'op50_process_time': 5.24514,
#   'op60_test': 0},
#  {'item_key': 5,
#   'body_l': 260.00665,
#   'body_w': 180.00650000000002,
#   'body_h': 50.00248,
#   'wavyfin_l': 100.00313,
#   'wavyfin_w': 50.00143,
#   'wavyfin_h': 59.99987,
#   'op10_l': 260.00665,
#   'op10_w': 180.00650000000002,
#   'op10_h': 59.99987,
#   'op10_electricity': 99.64106,
#   'op10_process_time': 14.36012,
#   'op10_test': 0,
#   'pipe1_l': 30.00378,
#   'pipe1_w': 49.99947,
#   'pipe1_h': 29.9988,
#   'op20_l': 260.00665,
#   'op20_w': 180.00650000000002,
#   'op20_h': 59.99987,
#   'op20_electricity': 95.03923,
#   'op20_process_time': 18.11253,
#   'op20_test': 0,
#   'pipe2_l': 30.00696,
#   'pipe2_w': 50.00268,
#   'pipe2_h': 30.00478,
#   'op30_l': 260.00665,
#   'op30_w': 180.00650000000002,
#   'op30_h': 59.99987,
#   'op30_electricity': 91.33982,
#   'op30_process_time': 3.72769,
#   'op30_test': 0,
#   'flange1_l': 30.00281,
#   'flange1_w': 79.99852,
#   'flange1_h': 40.00163,
#   'op40_l': 260.00665,
#   'op40_w': 180.00650000000002,
#   'op40_h': 59.99987,
#   'op40_temperature': 489.97845,
#   'op40_process_time': 4.18149,
#   'op40_test': 0,
#   'flange2_l': 29.99974,
#   'flange2_w': 79.99792,
#   'flange2_h': 39.99865,
#   'op50_l': 260.00665,
#   'op50_w': 180.00650000000002,
#   'op50_h': 59.99987,
#   'op50_temperature': 504.96622,
#   'op50_process_time': 0.78232,
#   'op60_test': 0},
#  {'item_key': 6,
#   'body_l': 259.99943,
#   'body_w': 179.99425,
#   'body_h': 49.99839,
#   'wavyfin_l': 99.99958,
#   'wavyfin_w': 50.00221,
#   'wavyfin_h': 59.99941,
#   'op10_l': 259.99943,
#   'op10_w': 179.99425,
#   'op10_h': 59.99941,
#   'op10_electricity': 89.79284,
#   'op10_process_time': 28.49964,
#   'op10_test': 0,
#   'pipe1_l': 30.00475,
#   'pipe1_w': 50.00017,
#   'pipe1_h': 29.9978,
#   'op20_l': 259.99943,
#   'op20_w': 179.99425,
#   'op20_h': 59.99941,
#   'op20_electricity': 95.16633,
#   'op20_process_time': 2.66348,
#   'op20_test': 0,
#   'pipe2_l': 30.00545,
#   'pipe2_w': 49.99863,
#   'pipe2_h': 29.99864,
#   'op30_l': 259.99943,
#   'op30_w': 179.99425,
#   'op30_h': 59.99941,
#   'op30_electricity': 92.2665,
#   'op30_process_time': 3.41538,
#   'op30_test': 0,
#   'flange1_l': 30.00585,
#   'flange1_w': 79.99828,
#   'flange1_h': 39.99966,
#   'op40_l': 259.99943,
#   'op40_w': 179.99425,
#   'op40_h': 59.99941,
#   'op40_temperature': 499.08438,
#   'op40_process_time': 1.48503,
#   'op40_test': 0,
#   'flange2_l': 29.99843,
#   'flange2_w': 80.00269,
#   'flange2_h': 39.99834,
#   'op50_l': 259.99943,
#   'op50_w': 179.99425,
#   'op50_h': 59.99941,
#   'op50_temperature': 493.82977,
#   'op50_process_time': 0.82806,
#   'op60_test': 0},
#  {'item_key': 7,
#   'body_l': 260.00347,
#   'body_w': 180.00456000000003,
#   'body_h': 50.00023,
#   'wavyfin_l': 100.00022,
#   'wavyfin_w': 50.00081,
#   'wavyfin_h': 60.00096,
#   'op10_l': 260.00347,
#   'op10_w': 180.00456000000003,
#   'op10_h': 60.00096,
#   'op10_electricity': 99.24957,
#   'op10_process_time': 12.2486,
#   'op10_test': 0,
#   'pipe1_l': 29.99869,
#   'pipe1_w': 50.00194,
#   'pipe1_h': 30.00466,
#   'op20_l': 260.00347,
#   'op20_w': 180.00456000000003,
#   'op20_h': 60.00096,
#   'op20_electricity': 91.35538,
#   'op20_process_time': 17.674,
#   'op20_test': 0,
#   'pipe2_l': 30.00291,
#   'pipe2_w': 50.00157,
#   'pipe2_h': 29.9996,
#   'op30_l': 260.00347,
#   'op30_w': 180.00456000000003,
#   'op30_h': 60.00096,
#   'op30_electricity': 93.01904,
#   'op30_process_time': 12.13668,
#   'op30_test': 0,
#   'flange1_l': 29.99992,
#   'flange1_w': 80.00243,
#   'flange1_h': 39.99989,
#   'op40_l': 260.00347,
#   'op40_w': 180.00456000000003,
#   'op40_h': 60.00096,
#   'op40_temperature': 503.24762,
#   'op40_process_time': 2.58796,
#   'op40_test': 0,
#   'flange2_l': 29.99642,
#   'flange2_w': 80.00134,
#   'flange2_h': 39.99503,
#   'op50_l': 260.00347,
#   'op50_w': 180.00456000000003,
#   'op50_h': 60.00096,
#   'op50_temperature': 510.08555,
#   'op50_process_time': 6.38669,
#   'op60_test': 0},
#  {'item_key': 8,
#   'body_l': 260.00013,
#   'body_w': 179.99581,
#   'body_h': 49.99945,
#   'wavyfin_l': 100.00071,
#   'wavyfin_w': 49.99774,
#   'wavyfin_h': 59.99964,
#   'op10_l': 260.00013,
#   'op10_w': 179.99581,
#   'op10_h': 59.99964,
#   'op10_electricity': 91.90404,
#   'op10_process_time': 2.67775,
#   'op10_test': 0,
#   'pipe1_l': 30.00067,
#   'pipe1_w': 49.9966,
#   'pipe1_h': 30.00114,
#   'op20_l': 260.00013,
#   'op20_w': 179.99581,
#   'op20_h': 59.99964,
#   'op20_electricity': 95.24517,
#   'op20_process_time': 4.09808,
#   'op20_test': 0,
#   'pipe2_l': 30.00021,
#   'pipe2_w': 50.00054,
#   'pipe2_h': 30.0013,
#   'op30_l': 260.00013,
#   'op30_w': 179.99581,
#   'op30_h': 59.99964,
#   'op30_electricity': 92.86401,
#   'op30_process_time': 11.49953,
#   'op30_test': 0,
#   'flange1_l': 29.99795,
#   'flange1_w': 79.99833,
#   'flange1_h': 40.00015,
#   'op40_l': 260.00013,
#   'op40_w': 179.99581,
#   'op40_h': 59.99964,
#   'op40_temperature': 495.79707,
#   'op40_process_time': 1.18979,
#   'op40_test': 0,
#   'flange2_l': 30.00364,
#   'flange2_w': 80.00037,
#   'flange2_h': 40.00047,
#   'op50_l': 260.00013,
#   'op50_w': 179.99581,
#   'op50_h': 59.99964,
#   'op50_temperature': 491.96044,
#   'op50_process_time': 10.18681,
#   'op60_test': 0},
#  {'item_key': 9,
#   'body_l': 260.00672000000003,
#   'body_w': 179.99869999999999,
#   'body_h': 49.99869,
#   'wavyfin_l': 100.00048,
#   'wavyfin_w': 50.00183,
#   'wavyfin_h': 60.00304,
#   'op10_l': 260.00672000000003,
#   'op10_w': 179.99869999999999,
#   'op10_h': 60.00304,
#   'op10_electricity': 96.23708,
#   'op10_process_time': 8.06099,
#   'op10_test': 0,
#   'pipe1_l': 29.99924,
#   'pipe1_w': 50.00027,
#   'pipe1_h': 30.00345,
#   'op20_l': 260.00672000000003,
#   'op20_w': 179.99869999999999,
#   'op20_h': 60.00304,
#   'op20_electricity': 95.05648,
#   'op20_process_time': 2.87181,
#   'op20_test': 0,
#   'pipe2_l': 29.99922,
#   'pipe2_w': 49.99835,
#   'pipe2_h': 29.99782,
#   'op30_l': 260.00672000000003,
#   'op30_w': 179.99869999999999,
#   'op30_h': 60.00304,
#   'op30_electricity': 93.40107,
#   'op30_process_time': 6.77855,
#   'op30_test': 0,
#   'flange1_l': 29.99962,
#   'flange1_w': 79.99848,
#   'flange1_h': 40.00113,
#   'op40_l': 260.00672000000003,
#   'op40_w': 179.99869999999999,
#   'op40_h': 60.00304,
#   'op40_temperature': 498.99159,
#   'op40_process_time': 0.34845,
#   'op40_test': 0,
#   'flange2_l': 30.00419,
#   'flange2_w': 80.00108,
#   'flange2_h': 40.00578,
#   'op50_l': 260.00672000000003,
#   'op50_w': 179.99869999999999,
#   'op50_h': 60.00304,
#   'op50_temperature': 494.66839,
#   'op50_process_time': 14.9693,
#   'op60_test': 0}]

# %%
result_df = pd.DataFrame(process())
result_df = result_df.set_index('item_key')

# %%
result_df.to_excel("item_data.xlsx")

# %%
data_load = pd.read_excel("item_data.xlsx")

num_list = len(data_load)

print(num_list)
data_load
# Out:
# 10
#    item_key    body_h     body_l      body_w  flange1_h  flange1_l  flange1_w  \
# 0         0  49.99872  260.00119  180.001610   40.00090   29.99802   80.00191
# 1         1  50.00132  260.00361  179.995230   39.99901   29.99929   80.00004
# 2         2  50.00091  259.99271  180.001310   39.99766   29.99886   79.99983
# 3         3  49.99613  260.00488  180.001210   39.99726   30.00131   79.99747
# 4         4  50.00158  260.00506  180.001330   40.00073   30.00262   80.00494
# 5         5  50.00113  260.00274  179.999440   39.99557   30.00246   79.99769
# 6         6  50.00050  260.00067  180.146616   39.99706   29.99866   80.00351
# 7         7  50.00324  260.00353  180.005020   39.99345   29.99963   80.00249
# 8         8  49.99810  260.00404  179.996180   40.00012   30.00294   80.00278
# 9         9  50.00013  260.00725  179.994940   39.99634   30.00116   79.99534
#
#    flange2_h  flange2_l  flange2_w  ...  op60_test   pipe1_h   pipe1_l  \
# 0   39.99847   30.00149   80.00036  ...          0  30.00073  29.99801
# 1   39.99781   30.00747   79.99691  ...          0  30.00026  29.99643
# 2   40.00177   29.99567   79.99996  ...          0  29.99922  29.99765
# 3   40.00075   30.00065   79.99910  ...          0  30.00209  29.99829
# 4   39.99190   30.00210   80.00298  ...          0  30.00442  30.00057
# 5   39.99859   30.00105   79.99691  ...          0  29.99972  29.99980
# 6   39.99687   30.00201   79.99891  ...          0  30.00014  30.00245
# 7   40.00116   30.00086   79.99835  ...          0  29.99733  30.00337
# 8   39.99787   29.99768   79.99766  ...          0  29.99722  30.00340
# 9   40.00226   30.00271   79.99954  ...          0  29.99669  29.99903
#
#     pipe1_w   pipe2_h   pipe2_l   pipe2_w  wavyfin_h  wavyfin_l  wavyfin_w
# 0  50.00044  29.99683  30.00075  50.00205   60.00305  100.00217   49.99999
# 1  49.99985  30.00356  29.99999  49.99584   60.00256   99.99609   50.00252
# 2  49.99714  30.00363  30.00027  50.00197   59.99676  100.00116   50.00487
# 3  50.00472  30.00504  30.00138  49.99852   59.99706   99.99967   50.00108
# 4  50.00485  29.99731  30.00133  49.99620   59.99990  100.00000   50.00057
# 5  50.00201  30.00467  29.99887  49.99567   59.99859  100.00043   50.00031
# 6  50.00134  29.99996  29.99794  50.00044   59.99679  100.00181   49.99784
# 7  49.99967  30.00061  29.99727  50.00519   59.99551   99.99769   50.00231
# 8  49.99886  29.99711  29.99757  49.99671   59.99733  100.00035   49.99992
# 9  49.99783  30.00099  29.99926  50.00080   60.00353  100.00057   50.00081
#
# [10 rows x 49 columns]
