# %% [markdown]
# # 공정 데이터 생성

# %%
import numpy as np
import pandas as pd
import time
from time import sleep

# %%
def parts():
    std = 0.0025
    amount = 100

    body_l = np.random.normal(200,std, amount)
    body_w = np.random.normal(100,std, amount)
    body_h = np.random.normal(50,std, amount)

    wavyfin_l = np.random.normal(100,std, amount)
    wavyfin_w = np.random.normal(50,std, amount)
    wavyfin_h = np.random.normal(60,std, amount)

    pipe1_l = np.random.normal(30,std, amount)
    pipe1_w = np.random.normal(50,std, amount)
    pipe1_h = np.random.normal(30,std, amount)

    pipe2_l = np.random.normal(30,std, amount)
    pipe2_w = np.random.normal(50,std, amount)
    pipe2_h = np.random.normal(30,std, amount)

    flange1_l = np.random.normal(30,std, amount)
    flange1_w = np.random.normal(80,std, amount)
    flange1_h = np.random.normal(40,std, amount)

    flange2_l = np.random.normal(30,std, amount)
    flange2_w = np.random.normal(80,std, amount)
    flange2_h = np.random.normal(40,std, amount)
    
    return body_l, body_w, body_h, wavyfin_l, wavyfin_w, wavyfin_h, pipe1_l, pipe1_w, pipe1_h, pipe2_l, pipe2_w, pipe2_h, flange1_l, flange1_w, flange1_h, flange2_l, flange2_w, flange2_h

# %%
parts()
# Out:
# (array([199.99999624, 200.00039307, 199.99676291, 200.00175987,
#         200.00118395, 200.00388537, 200.00003856, 199.99993965,
#         199.99989283, 199.99680914, 199.99650182, 200.00115256,
#         200.00015325, 200.00511712, 200.00097091, 199.99854309,
#         200.00377323, 200.00970731, 200.00323884, 199.99788489,
#         199.99920869, 200.00073021, 200.00097615, 199.99775623,
#         199.99940125, 199.99866264, 199.99911643, 200.00506509,
#         199.99768902, 200.00373324, 200.00284376, 200.00016343,
#         199.99927217, 199.99887538, 200.00036752, 199.99762642,
#         200.00123949, 199.99939027, 200.00592757, 199.99607241,
#         200.00171943, 200.0012552 , 200.00226493, 199.99845114,
#         200.00020749, 199.99854629, 200.00417063, 199.99658514,
#         199.99799414, 199.99768154, 200.0004123 , 200.00054164,
#         200.00287536, 200.00309343, 199.99719856, 199.99944093,
#         200.00160793, 199.99986028, 200.00375193, 199.99782826,
#         200.00197734, 199.99749949, 200.00337873, 199.99818075,
#         200.00404412, 200.00102896, 199.99975082, 200.00302517,
#         200.00126528, 199.99506818, 199.99771628, 199.9988712 ,
#         199.99982754, 199.99456157, 200.00265111, 199.99961306,
#         199.99848856, 200.00144753, 200.00118401, 200.00501354,
#         199.99912785, 199.99923828, 199.99646438, 200.00107275,
#         200.00135448, 199.99518678, 199.99663769, 199.99972793,
#         199.9973719 , 200.00009462, 200.00105967, 199.99977398,
#         199.99956739, 199.99855092, 199.99771665, 200.00105142,
#         199.9998545 , 199.99708915, 200.00027516, 199.99761488]),
#  array([ 99.99948548,  99.99750543, 100.0038589 ,  99.997031  ,
#         100.00299404,  99.99842093, 100.00442278, 100.00554693,
#          99.99811547, 100.00149687,  99.9983959 ,  99.997503  ,
#         100.00161365, 100.00100565, 100.00038419, 100.00464578,
#          99.99867453,  99.99683762, 100.00003343, 100.00110458,
#         100.00167501, 100.00154981,  99.99829906,  99.99610973,
#         39.99998621, 40.00384881, 40.00479097, 39.9992381 , 39.99862304,
#         39.99970893, 40.00275132, 40.00018808, 39.99899847, 39.99847045,
#         39.99788327, 39.99629711, 39.99997198, 39.99742687, 40.00119475,
#         40.00007388, 39.99688889, 39.99881066, 40.00142786, 40.00283794,
#         39.99526211, 40.00139709, 39.99962028, 39.99456854, 40.00284641,
#         40.00012332, 39.99740938, 39.99742178, 40.00234741, 40.00006299]))

# %%
def process():
    item_data = []
    std = 0.0025
    amount = 10
    body_l = np.random.normal(200,std, amount)
    body_l = body_l.round(5)
    body_w = np.random.normal(100,std, amount)
    body_w = body_w.round(5)
    body_h = np.random.normal(50,std, amount)
    body_h = body_h.round(5)
    
    wavyfin_l = np.random.normal(100,std, amount)
    wavyfin_l = wavyfin_l.round(5)
    wavyfin_w = np.random.normal(50,std, amount)
    wavyfin_w = wavyfin_w.round(5)
    wavyfin_h = np.random.normal(60,std, amount)
    wavyfin_h = wavyfin_h.round(5)
    
    op10_electricity = np.random.uniform(89, 100, amount)
    op10_electricity = op10_electricity.round(5)
    
    op10_l = body_l
    op10_w = body_w
    op10_h = wavyfin_h
    
    ############################################################################
    
    pipe1_l = np.random.normal(30,std, amount)
    pipe1_l = pipe1_l.round(5)
    pipe1_w = np.random.normal(50,std, amount)
    pipe1_w = pipe1_w.round(5)
    pipe1_h = np.random.normal(30,std, amount)
    pipe1_h = pipe1_h.round(5)
    
    op20_electricity = np.random.uniform(89, 100, amount)
    op20_electricity = op20_electricity.round(5)
    
    op20_l = op10_l
    op20_w = body_w + pipe1_w
    for item_20 in range(amount):
        
        if op20_electricity[item_20] < 90:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - op20_electricity[item_20] * 0.11
        else:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - 1        
    op10_h = wavyfin_h
    
    ############################################################################
    
    pipe2_l = np.random.normal(30,std, amount)
    pipe2_l = pipe2_l.round(5)
    pipe2_w = np.random.normal(50,std, amount)
    pipe2_w = pipe2_w.round(5)
    pipe2_h = np.random.normal(30,std, amount)
    pipe2_h = pipe2_h.round(5)
    
    op30_electricity = np.random.uniform(89, 100, amount)
    op30_electricity = op30_electricity.round(5)
    
    ############################################################################
    
    flange1_l = np.random.normal(30,std, amount)
    flange1_l = flange1_l.round(5)
    flange1_w = np.random.normal(80,std, amount)
    flange1_w = flange1_w.round(5)
    flange1_h = np.random.normal(40,std, amount)
    flange1_h = flange1_h.round(5)
    
    op40_temperature = np.random.uniform(489, 511, amount)
    op40_temperature = op40_temperature.round(5)
    
    ############################################################################
    
    flange2_l = np.random.normal(30,std, amount)
    flange2_l = flange2_l.round(5)
    flange2_w = np.random.normal(80,std, amount)
    flange2_w = flange2_w.round(5)
    flange2_h = np.random.normal(40,std, amount)
    flange2_h = flange2_h.round(5)
    
    op50_temperature = np.random.uniform(489, 511, amount)
    op50_temperature = op50_temperature.round(5)
    
    ############################################################################
    
    op10_process_time = np.random.exponential(10, amount)
    op10_process_time = op10_process_time.round(5)
    
    op20_process_time = np.random.exponential(10, amount)
    op20_process_time = op20_process_time.round(5)
    
    op30_process_time = np.random.exponential(10, amount)
    op30_process_time = op30_process_time.round(5)
    
    op40_process_time = np.random.exponential(10, amount)
    op40_process_time = op40_process_time.round(5)
    
    op50_process_time = np.random.exponential(10, amount)
    op50_process_time = op50_process_time.round(5)
    
    ############################################################################
    
    for i in range(amount):
        item = {}
        item['item_key'] = i
        item['body_l'] = body_l[i]
        item['body_w'] = body_w[i]
        item['body_h'] = body_h[i]
        
        item['wavyfin_l'] = wavyfin_l[i]
        item['wavyfin_w'] = wavyfin_w[i]
        item['wavyfin_h'] = wavyfin_h[i]
        
        item['op10_l'] = body_l[i]
        item['op10_w'] = body_w[i]
        item['op10_h'] = wavyfin_h[i]
        item['op10_electricity'] = op10_electricity[i]

        item['pipe1_l'] = pipe1_l[i]
        item['pipe1_w'] = pipe1_w[i]
        item['pipe1_h'] = pipe1_h[i]
        
        item['op20_l'] = body_l[i]            
        item['op20_w'] = body_w[i]
        item['op20_h'] = wavyfin_h[i]
        item['op20_electricity'] = op20_electricity[i]
        
        
        
        
        
        
        
        
        item_data.append(item)
    
        
    return item_data

# %%
process()
# Out:
# [{'item_key': 0,
#   'body_l': 199.99902,
#   'body_w': 100.00341,
#   'body_h': 49.99941,
#   'wavyfin_l': 99.99995,
#   'wavyfin_w': 50.0,
#   'wavyfin_h': 59.99691,
#   'op10_l': 199.99902,
#   'op10_w': 100.00341,
#   'op10_h': 59.99691,
#   'op10_electricity': 94.82051,
#   'pipe1_l': 30.0007,
#   'pipe1_w': 49.99904,
#   'pipe1_h': 29.99765,
#   'op20_l': 199.99902,
#   'op20_w': 100.00341,
#   'op20_h': 59.99691,
#   'op20_electricity': 89.73471},
#  {'item_key': 1,
#   'body_l': 200.0046,
#   'body_w': 99.99743,
#   'body_h': 50.00063,
#   'wavyfin_l': 99.99865,
#   'wavyfin_w': 49.99972,
#   'wavyfin_h': 59.99605,
#   'op10_l': 200.0046,
#   'op10_w': 99.99743,
#   'op10_h': 59.99605,
#   'op10_electricity': 89.58387,
#   'pipe1_l': 30.00171,
#   'pipe1_w': 50.00067,
#   'pipe1_h': 29.99992,
#   'op20_l': 200.0046,
#   'op20_w': 99.99743,
#   'op20_h': 59.99605,
#   'op20_electricity': 99.20504},
#  {'item_key': 2,
#   'body_l': 199.99681,
#   'body_w': 99.99984,
#   'body_h': 50.00173,
#   'wavyfin_l': 100.00346,
#   'wavyfin_w': 49.99823,
#   'wavyfin_h': 60.00105,
#   'op10_l': 199.99681,
#   'op10_w': 99.99984,
#   'op10_h': 60.00105,
#   'op10_electricity': 94.17043,
#   'pipe1_l': 29.99725,
#   'pipe1_w': 50.00027,
#   'pipe1_h': 30.00301,
#   'op20_l': 199.99681,
#   'op20_w': 99.99984,
#   'op20_h': 60.00105,
#   'op20_electricity': 97.97599},
#  {'item_key': 3,
#   'body_l': 199.99981,
#   'body_w': 99.9982,
#   'body_h': 49.99925,
#   'wavyfin_l': 100.00141,
#   'wavyfin_w': 49.99881,
#   'wavyfin_h': 59.99566,
#   'op10_l': 199.99981,
#   'op10_w': 99.9982,
#   'op10_h': 59.99566,
#   'op10_electricity': 92.62565,
#   'pipe1_l': 29.99767,
#   'pipe1_w': 49.99875,
#   'pipe1_h': 30.00123,
#   'op20_l': 199.99981,
#   'op20_w': 99.9982,
#   'op20_h': 59.99566,
#   'op20_electricity': 89.27555},
#  {'item_key': 4,
#   'body_l': 200.0018,
#   'body_w': 99.99793,
#   'body_h': 50.00057,
#   'wavyfin_l': 99.99824,
#   'wavyfin_w': 50.00036,
#   'wavyfin_h': 59.99812,
#   'op10_l': 200.0018,
#   'op10_w': 99.99793,
#   'op10_h': 59.99812,
#   'op10_electricity': 98.35656,
#   'pipe1_l': 29.99785,
#   'pipe1_w': 49.99786,
#   'pipe1_h': 30.00129,
#   'op20_l': 200.0018,
#   'op20_w': 99.99793,
#   'op20_h': 59.99812,
#   'op20_electricity': 99.9167},
#  {'item_key': 5,
#   'body_l': 199.99711,
#   'body_w': 99.99663,
#   'body_h': 50.00083,
#   'wavyfin_l': 100.00152,
#   'wavyfin_w': 49.99652,
#   'wavyfin_h': 59.99954,
#   'op10_l': 199.99711,
#   'op10_w': 99.99663,
#   'op10_h': 59.99954,
#   'op10_electricity': 94.54556,
#   'pipe1_l': 30.00001,
#   'pipe1_w': 49.99778,
#   'pipe1_h': 30.00197,
#   'op20_l': 199.99711,
#   'op20_w': 99.99663,
#   'op20_h': 59.99954,
#   'op20_electricity': 95.37134},
#  {'item_key': 6,
#   'body_l': 199.99726,
#   'body_w': 100.00209,
#   'body_h': 50.00682,
#   'wavyfin_l': 100.00178,
#   'wavyfin_w': 49.99635,
#   'wavyfin_h': 60.00033,
#   'op10_l': 199.99726,
#   'op10_w': 100.00209,
#   'op10_h': 60.00033,
#   'op10_electricity': 92.8154,
#   'pipe1_l': 30.00107,
#   'pipe1_w': 49.99791,
#   'pipe1_h': 29.99813,
#   'op20_l': 199.99726,
#   'op20_w': 100.00209,
#   'op20_h': 60.00033,
#   'op20_electricity': 91.65101},
#  {'item_key': 7,
#   'body_l': 199.99907,
#   'body_w': 100.00014,
#   'body_h': 49.99689,
#   'wavyfin_l': 99.99566,
#   'wavyfin_w': 50.00004,
#   'wavyfin_h': 60.002,
#   'op10_l': 199.99907,
#   'op10_w': 100.00014,
#   'op10_h': 60.002,
#   'op10_electricity': 95.00954,
#   'pipe1_l': 29.99667,
#   'pipe1_w': 49.9997,
#   'pipe1_h': 30.00117,
#   'op20_l': 199.99907,
#   'op20_w': 100.00014,
#   'op20_h': 60.002,
#   'op20_electricity': 92.26196},
#  {'item_key': 8,
#   'body_l': 200.00245,
#   'body_w': 99.99958,
#   'body_h': 49.99815,
#   'wavyfin_l': 99.99947,
#   'wavyfin_w': 50.00038,
#   'wavyfin_h': 60.00073,
#   'op10_l': 200.00245,
#   'op10_w': 99.99958,
#   'op10_h': 60.00073,
#   'op10_electricity': 92.77465,
#   'pipe1_l': 30.00007,
#   'pipe1_w': 50.00117,
#   'pipe1_h': 30.00276,
#   'op20_l': 200.00245,
#   'op20_w': 99.99958,
#   'op20_h': 60.00073,
#   'op20_electricity': 99.02026},
#  {'item_key': 9,
#   'body_l': 200.00434,
#   'body_w': 100.00264,
#   'body_h': 50.00066,
#   'wavyfin_l': 100.00262,
#   'wavyfin_w': 49.99594,
#   'wavyfin_h': 60.0,
#   'op10_l': 200.00434,
#   'op10_w': 100.00264,
#   'op10_h': 60.0,
#   'op10_electricity': 90.41371,
#   'pipe1_l': 30.00007,
#   'pipe1_w': 49.99809,
#   'pipe1_h': 30.0027,
#   'op20_l': 200.00434,
#   'op20_w': 100.00264,
#   'op20_h': 60.0,
#   'op20_electricity': 98.60903}]

# %%
result_df = pd.DataFrame(op10())
result_df = result_df.set_index('item_key')

# %%
result_df.to_excel("op10_data.xlsx")

# %%
data_load = pd.read_excel("op10_data.xlsx")

num_list = len(data_load)

print(num_list)
data_load
# Out:
# 10
#    item_key    body_h     body_l     body_w  op10_electricity    op10_h  \
# 0         0  49.99981  199.99733  100.00162          90.90914  60.00117
# 1         1  49.99724  200.00037  100.00012          95.16732  59.99892
# 2         2  50.00088  200.00101   99.99829          99.80044  59.99243
# 3         3  49.99991  200.00245  100.00153          95.30935  59.99842
# 4         4  49.99734  199.99780  100.00133          92.25023  59.99466
# 5         5  49.99698  199.99763  100.00069          89.12407  60.00328
# 6         6  49.99918  200.00049   99.99898          92.13444  59.99982
# 7         7  50.00411  200.00188   99.99720          98.50394  59.99908
# 8         8  49.99848  200.00182   99.99636          90.42665  59.99476
# 9         9  49.99971  199.99695   99.99512          95.88085  59.99840
#
#       op10_l     op10_w  wavyfin_h  wavyfin_l  wavyfin_w
# 0  199.99733  100.00162   60.00117   99.99705   49.99996
# 1  200.00037  100.00012   59.99892   99.99904   49.99994
# 2  200.00101   99.99829   59.99243   99.99854   49.99828
# 3  200.00245  100.00153   59.99842   99.99651   49.99864
# 4  199.99780  100.00133   59.99466   99.99918   50.00049
# 5  199.99763  100.00069   60.00328   99.99963   49.99691
# 6  200.00049   99.99898   59.99982   99.99950   49.99772
# 7  200.00188   99.99720   59.99908  100.00093   50.00020
# 8  200.00182   99.99636   59.99476  100.00256   50.00532
# 9  199.99695   99.99512   59.99840   99.99524   49.99629

# %%
def op20():
    item_data = []
    std = 0.0025
    amount = 10
    pipe1_l = np.random.normal(200,std, amount)
    pipe1_l = body_l.round(5)
    pipe1_w = np.random.normal(100,std, amount)
    pipe1_w = body_w.round(5)
    pipe1_h = np.random.normal(50,std, amount)
    pipe1_h = body_h.round(5)
    
    op20_electricity = np.random.uniform(89, 100, amount)
    op20_electricity = op10_electricity.round(5)
    
    for i in range(amount):
        item = {}
        item['item_key'] = i
        item['body_l'] = body_l[i]
        item['body_w'] = body_w[i]
        item['body_h'] = body_h[i]
        
        item['wavyfin_l'] = wavyfin_l[i]
        item['wavyfin_w'] = wavyfin_w[i]
        item['wavyfin_h'] = wavyfin_h[i]
        
        item['op10_l'] = body_l[i]
        item['op10_w'] = body_w[i]
        item['op10_h'] = wavyfin_h[i]
        
        item['op10_electricity'] = op10_electricity[i]
        
        item_data.append(item)
        
    return item_data
