# %% [markdown]
# # 공정 데이터 생성

# %%
import numpy as np
import pandas as pd
import time
from time import sleep
from datetime import datetime

# %%
time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
print(time_stamp)

# sleep을 실행시킬 때는 나두고 time_stamp 저장할 때 바꾸는 방법 고려
# Out:
# 2020-09-26 11:16:22

# %%
def process():
    item_data = []
    std = 0.0025 # 표준편차
    amount = 10 # 생성 아이템 갯수
    
    makespan = 0 # 총처리 시간
    
    speed = 0.01 # 배수 적어지면 적어질수록 빨라짐
    
    ############################################################################
    # 처리시간 생성
    op10_process_time = np.random.exponential(10, amount)
    op10_process_time = op10_process_time.round(5)
    
    op20_process_time = np.random.exponential(10, amount)
    op20_process_time = op20_process_time.round(5)
    
    op30_process_time = np.random.exponential(10, amount)
    op30_process_time = op30_process_time.round(5)
    
    op40_process_time = np.random.exponential(10, amount)
    op40_process_time = op40_process_time.round(5)
    
    op50_process_time = np.random.exponential(10, amount)
    op50_process_time = op50_process_time.round(5)
    
    op60_process_time = np.random.exponential(10, amount)
    op60_process_time = op60_process_time.round(5)
    
    ############################################################################
    # op10
    body_l = np.random.normal(200,std, amount)
    body_l = body_l.round(5)
    body_w = np.random.normal(100,std, amount)
    body_w = body_w.round(5)
    body_h = np.random.normal(50,std, amount)
    body_h = body_h.round(5)
    
    wavyfin_l = np.random.normal(100,std, amount)
    wavyfin_l = wavyfin_l.round(5)
    wavyfin_w = np.random.normal(50,std, amount)
    wavyfin_w = wavyfin_w.round(5)
    wavyfin_h = np.random.normal(60,std, amount)
    wavyfin_h = wavyfin_h.round(5)
    
    op10_electricity = np.random.uniform(89, 100, amount)
    op10_electricity = op10_electricity.round(5)
    
    op10_l = body_l
    op10_w = body_w
    op10_h = wavyfin_h
    
    op10_time_stamp = []
    
    for process in range(amount):
        
        op10_l[process] = body_l[process]
        op10_w[process] = body_w[process]
        op10_h[process] = wavyfin_h[process]
    
        time.sleep(op10_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op10_time_stamp.append(time_stamp)
    
    op10_test = []
    
    for test in range(amount):
    
        if (op10_l[test] < 199.99) or (op10_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op10_w[test] < 99.99) or (op10_w[test] > 100.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op10_h[test] < 59.99) or (op10_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op10_test.append(0)
        else:
            op10_test.append(1)
    
    ############################################################################
    # op20
    pipe1_l = np.random.normal(30,std, amount)
    pipe1_l = pipe1_l.round(5)
    pipe1_w = np.random.normal(50,std, amount)
    pipe1_w = pipe1_w.round(5)
    pipe1_h = np.random.normal(30,std, amount)
    pipe1_h = pipe1_h.round(5)
    
    op20_electricity = np.random.uniform(89, 100, amount)
    op20_electricity = op20_electricity.round(5)
    
    op20_l = op10_l
    op20_w = body_w
    op20_h = op10_h
    
    op20_time_stamp = []
    
    for process in range(amount):
        
        op20_l[process] = op10_l[process]
        op20_w[process] = body_w[process]
        op20_h[process] = op10_h[process]
    
        time.sleep(op20_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op20_time_stamp.append(time_stamp)
    
    for item_20 in range(amount):
        
        if op20_electricity[item_20] < 90:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - op20_electricity[item_20] * 0.11
        else:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - 10
            
    op20_test = []
    
    for test in range(amount):
    
        if (op20_l[test] < 199.99) or (op20_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op20_w[test] < 139.99) or (op20_w[test] > 140.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op20_h[test] < 59.99) or (op20_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op20_test.append(0)
        else:
            op20_test.append(1)
    
    ############################################################################
    
    pipe2_l = np.random.normal(30,std, amount)
    pipe2_l = pipe2_l.round(5)
    pipe2_w = np.random.normal(50,std, amount)
    pipe2_w = pipe2_w.round(5)
    pipe2_h = np.random.normal(30,std, amount)
    pipe2_h = pipe2_h.round(5)
    
    op30_electricity = np.random.uniform(89, 100, amount)
    op30_electricity = op30_electricity.round(5)
    
    op30_l = op20_l
    op30_w = op20_w
    op30_h = op20_h
    
    op30_time_stamp = []
    
    for process in range(amount):
        
        op30_l[process] = op20_l[process]
        op30_w[process] = op20_w[process]
        op30_h[process] = op20_h[process]
    
        time.sleep(op30_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op30_time_stamp.append(time_stamp)
    
    for item_30 in range(amount):
        
        if op30_electricity[item_30] < 90:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - op30_electricity[item_30] * 0.11
        else:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - 10

    op30_test = []
    
    for test in range(amount):
    
        if (op30_l[test] < 199.99) or (op30_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op30_w[test] < 179.99) or (op30_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op30_h[test] < 59.99) or (op30_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op30_test.append(0)
        else:
            op30_test.append(1)
    
    ############################################################################
    
    flange1_l = np.random.normal(30,std, amount)
    flange1_l = flange1_l.round(5)
    flange1_w = np.random.normal(80,std, amount)
    flange1_w = flange1_w.round(5)
    flange1_h = np.random.normal(40,std, amount)
    flange1_h = flange1_h.round(5)
    
    op40_temperature = np.random.uniform(489, 511, amount)
    op40_temperature = op40_temperature.round(5)
    
    op40_l = op30_l
    op40_w = op30_w
    op40_h = op30_h
    
    op40_time_stamp = []
    
    for process in range(amount):
        
        op40_l[process] = op30_l[process]
        op40_w[process] = op30_w[process]
        op40_h[process] = op30_h[process]
    
        time.sleep(op40_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op40_time_stamp.append(time_stamp)
    
    for item_40 in range(amount):
        
        if 489 < op40_temperature[item_40] < 511:
            op40_l[item_40] = op30_l[item_40] + flange1_l[item_40]
        else:
            op40_l[item_40] = 0

    op40_test = []
    
    for test in range(amount):
    
        if (op40_l[test] < 229.99) or (op40_l[test] > 230.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op40_w[test] < 179.99) or (op40_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op40_h[test] < 59.99) or (op40_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op40_test.append(0)
        else:
            op40_test.append(1)
    
    ############################################################################
    
    flange2_l = np.random.normal(30,std, amount)
    flange2_l = flange2_l.round(5)
    flange2_w = np.random.normal(80,std, amount)
    flange2_w = flange2_w.round(5)
    flange2_h = np.random.normal(40,std, amount)
    flange2_h = flange2_h.round(5)
    
    op50_temperature = np.random.uniform(489, 511, amount)
    op50_temperature = op50_temperature.round(5)
    
    op50_l = op40_l
    op50_w = op40_w
    op50_h = op40_h
    
    op50_time_stamp = []
    
    for process in range(amount):
        
        op50_l[process] = op40_l[process]
        op50_w[process] = op40_w[process]
        op50_h[process] = op40_h[process]
    
        time.sleep(op50_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op50_time_stamp.append(time_stamp)
    
    for item_50 in range(amount):
        
        if 489 < op50_temperature[item_50] < 511:
            op50_l[item_50] = op40_l[item_50] + flange2_l[item_50]
        else:
            op50_l[item_50] = 0

    
    ############################################################################
    
    op60_time_stamp = []
    
    op60_l = op50_l
    op60_w = op50_w
    op60_h = op50_h
    
    for process in range(amount):
        
        op60_l[process] = op50_l[process]
        op60_w[process] = op50_w[process]
        op60_h[process] = op50_h[process]
    
        time.sleep(op60_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op60_time_stamp.append(time_stamp)
        
    op60_test = []
    
    for test in range(amount):
    
        if (op50_l[test] < 259.99) or (op50_l[test] > 260.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op50_w[test] < 179.99) or (op50_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op50_h[test] < 59.99) or (op50_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op60_test.append(0)
        else:
            op60_test.append(1)
            
    ############################################################################
    
    for i in range(amount):
        item = {}
        item['item_key'] = i
        item['body_l'] = body_l[i]
        item['body_w'] = body_w[i]
        item['body_h'] = body_h[i]
        
        item['wavyfin_l'] = wavyfin_l[i]
        item['wavyfin_w'] = wavyfin_w[i]
        item['wavyfin_h'] = wavyfin_h[i]
        
        item['op10_l'] = body_l[i]
        item['op10_w'] = body_w[i]
        item['op10_h'] = wavyfin_h[i]
        item['op10_electricity'] = op10_electricity[i]
        item['op10_process_time'] = op10_process_time[i]
        item['op10_test'] = op10_test[i]
        item['op10_time_stamp'] = op10_time_stamp[i]

        item['pipe1_l'] = pipe1_l[i]
        item['pipe1_w'] = pipe1_w[i]
        item['pipe1_h'] = pipe1_h[i]
        
        item['op20_l'] = op20_l[i]            
        item['op20_w'] = op20_w[i]
        item['op20_h'] = op20_h[i]
        item['op20_electricity'] = op20_electricity[i]
        item['op20_process_time'] = op20_process_time[i]
        item['op20_test'] = op20_test[i]
        item['op20_time_stamp'] = op20_time_stamp[i]
        
        item['pipe2_l'] = pipe2_l[i]
        item['pipe2_w'] = pipe2_w[i]
        item['pipe2_h'] = pipe2_h[i]
        
        item['op30_l'] = op30_l[i]            
        item['op30_w'] = op30_w[i]
        item['op30_h'] = op30_h[i]
        item['op30_electricity'] = op30_electricity[i]
        item['op30_process_time'] = op30_process_time[i]
        item['op30_test'] = op30_test[i]
        item['op30_time_stamp'] = op30_time_stamp[i]
        
        item['flange1_l'] = flange1_l[i]
        item['flange1_w'] = flange1_w[i]
        item['flange1_h'] = flange1_h[i]
        
        item['op40_l'] = op40_l[i]            
        item['op40_w'] = op40_w[i]
        item['op40_h'] = op40_h[i]
        item['op40_temperature'] = op40_temperature[i]
        item['op40_process_time'] = op40_process_time[i]
        item['op40_test'] = op40_test[i]
        item['op40_time_stamp'] = op40_time_stamp[i]
        
        item['flange2_l'] = flange2_l[i]
        item['flange2_w'] = flange2_w[i]
        item['flange2_h'] = flange2_h[i]
        
        item['op50_l'] = op50_l[i]            
        item['op50_w'] = op50_w[i]
        item['op50_h'] = op50_h[i]
        item['op50_temperature'] = op50_temperature[i]
        item['op50_process_time'] = op50_process_time[i]
        item['op50_time_stamp'] = op50_time_stamp[i]
        
        item['op60_l'] = op60_l[i]            
        item['op60_w'] = op60_w[i]
        item['op60_h'] = op60_h[i]
        item['op60_process_time'] = op60_process_time[i]
        item['op60_test'] = op60_test[i]
        item['op60_time_stamp'] = op60_time_stamp[i]
        
        item_data.append(item)
    
    return item_data

# %%
process()
# Out:
# [{'item_key': 0,
#   'body_l': 259.9995,
#   'body_w': 180.00079,
#   'body_h': 50.00072,
#   'wavyfin_l': 100.00441,
#   'wavyfin_w': 50.00032,
#   'wavyfin_h': 59.9992,
#   'op10_l': 259.9995,
#   'op10_w': 180.00079,
#   'op10_h': 59.9992,
#   'op10_electricity': 92.05715,
#   'op10_process_time': 11.24037,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:26',
#   'pipe1_l': 29.99869,
#   'pipe1_w': 49.99631,
#   'pipe1_h': 30.00045,
#   'op20_l': 259.9995,
#   'op20_w': 180.00079,
#   'op20_h': 59.9992,
#   'op20_electricity': 93.07352,
#   'op20_process_time': 3.67385,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 30.00024,
#   'pipe2_w': 50.00432,
#   'pipe2_h': 29.99776,
#   'op30_l': 259.9995,
#   'op30_w': 180.00079,
#   'op30_h': 59.9992,
#   'op30_electricity': 99.39435,
#   'op30_process_time': 8.07766,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 30.00013,
#   'flange1_w': 79.99671,
#   'flange1_h': 40.00194,
#   'op40_l': 259.9995,
#   'op40_w': 180.00079,
#   'op40_h': 59.9992,
#   'op40_temperature': 507.1966,
#   'op40_process_time': 6.37658,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:28',
#   'flange2_l': 29.9977,
#   'flange2_w': 79.99635,
#   'flange2_h': 40.00114,
#   'op50_l': 259.9995,
#   'op50_w': 180.00079,
#   'op50_h': 59.9992,
#   'op50_temperature': 502.17899,
#   'op50_process_time': 0.63709,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 259.9995,
#   'op60_w': 180.00079,
#   'op60_h': 59.9992,
#   'op60_process_time': 12.73572,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:30'},
#  {'item_key': 1,
#   'body_l': 260.00307,
#   'body_w': 179.99111,
#   'body_h': 50.00399,
#   'wavyfin_l': 99.99761,
#   'wavyfin_w': 50.00118,
#   'wavyfin_h': 60.00432,
#   'op10_l': 260.00307,
#   'op10_w': 179.99111,
#   'op10_h': 60.00432,
#   'op10_electricity': 93.82395,
#   'op10_process_time': 8.20812,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:26',
#   'pipe1_l': 30.00083,
#   'pipe1_w': 49.99301,
#   'pipe1_h': 29.9996,
#   'op20_l': 260.00307,
#   'op20_w': 179.99111,
#   'op20_h': 60.00432,
#   'op20_electricity': 91.92818,
#   'op20_process_time': 0.17732,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 30.00522,
#   'pipe2_w': 49.99928,
#   'pipe2_h': 30.00019,
#   'op30_l': 260.00307,
#   'op30_w': 179.99111,
#   'op30_h': 60.00432,
#   'op30_electricity': 90.88222,
#   'op30_process_time': 12.30026,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 30.00026,
#   'flange1_w': 79.99967,
#   'flange1_h': 39.99964,
#   'op40_l': 260.00307,
#   'op40_w': 179.99111,
#   'op40_h': 60.00432,
#   'op40_temperature': 497.16285,
#   'op40_process_time': 31.1379,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 30.00227,
#   'flange2_w': 79.99997,
#   'flange2_h': 39.99833,
#   'op50_l': 260.00307,
#   'op50_w': 179.99111,
#   'op50_h': 60.00432,
#   'op50_temperature': 491.83584,
#   'op50_process_time': 0.4934,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 260.00307,
#   'op60_w': 179.99111,
#   'op60_h': 60.00432,
#   'op60_process_time': 1.64855,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:30'},
#  {'item_key': 2,
#   'body_l': 260.00158000000005,
#   'body_w': 180.00408,
#   'body_h': 49.99982,
#   'wavyfin_l': 99.99879,
#   'wavyfin_w': 49.9968,
#   'wavyfin_h': 60.0035,
#   'op10_l': 260.00158000000005,
#   'op10_w': 180.00408,
#   'op10_h': 60.0035,
#   'op10_electricity': 93.66198,
#   'op10_process_time': 1.22489,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:26',
#   'pipe1_l': 29.99974,
#   'pipe1_w': 50.00118,
#   'pipe1_h': 30.00148,
#   'op20_l': 260.00158000000005,
#   'op20_w': 180.00408,
#   'op20_h': 60.0035,
#   'op20_electricity': 97.10717,
#   'op20_process_time': 7.53487,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 29.99709,
#   'pipe2_w': 50.00438,
#   'pipe2_h': 29.99921,
#   'op30_l': 260.00158000000005,
#   'op30_w': 180.00408,
#   'op30_h': 60.0035,
#   'op30_electricity': 91.45815,
#   'op30_process_time': 8.17007,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 29.99994,
#   'flange1_w': 80.0012,
#   'flange1_h': 40.00168,
#   'op40_l': 260.00158000000005,
#   'op40_w': 180.00408,
#   'op40_h': 60.0035,
#   'op40_temperature': 508.37041,
#   'op40_process_time': 13.58611,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 30.00151,
#   'flange2_w': 79.99667,
#   'flange2_h': 39.9973,
#   'op50_l': 260.00158000000005,
#   'op50_w': 180.00408,
#   'op50_h': 60.0035,
#   'op50_temperature': 505.58631,
#   'op50_process_time': 0.19605,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 260.00158000000005,
#   'op60_w': 180.00408,
#   'op60_h': 60.0035,
#   'op60_process_time': 2.0826,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:30'},
#  {'item_key': 3,
#   'body_l': 260.00372,
#   'body_w': 180.20567720000003,
#   'body_h': 49.99754,
#   'wavyfin_l': 99.99627,
#   'wavyfin_w': 50.00256,
#   'wavyfin_h': 60.00004,
#   'op10_l': 260.00372,
#   'op10_w': 180.20567720000003,
#   'op10_h': 60.00004,
#   'op10_electricity': 99.41243,
#   'op10_process_time': 0.53961,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:26',
#   'pipe1_l': 29.99706,
#   'pipe1_w': 49.99873,
#   'pipe1_h': 30.00092,
#   'op20_l': 260.00372,
#   'op20_w': 180.20567720000003,
#   'op20_h': 60.00004,
#   'op20_electricity': 93.7614,
#   'op20_process_time': 1.71537,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 30.00284,
#   'pipe2_w': 50.00207,
#   'pipe2_h': 29.99954,
#   'op30_l': 260.00372,
#   'op30_w': 180.20567720000003,
#   'op30_h': 60.00004,
#   'op30_electricity': 89.05348,
#   'op30_process_time': 5.55712,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 30.00057,
#   'flange1_w': 79.99927,
#   'flange1_h': 40.00231,
#   'op40_l': 260.00372,
#   'op40_w': 180.20567720000003,
#   'op40_h': 60.00004,
#   'op40_temperature': 501.17063,
#   'op40_process_time': 15.48551,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 30.00146,
#   'flange2_w': 79.99743,
#   'flange2_h': 39.9999,
#   'op50_l': 260.00372,
#   'op50_w': 180.20567720000003,
#   'op50_h': 60.00004,
#   'op50_temperature': 509.02858,
#   'op50_process_time': 4.83977,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 260.00372,
#   'op60_w': 180.20567720000003,
#   'op60_h': 60.00004,
#   'op60_process_time': 6.94034,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:30'},
#  {'item_key': 4,
#   'body_l': 260.00651,
#   'body_w': 179.99712,
#   'body_h': 49.99743,
#   'wavyfin_l': 100.00234,
#   'wavyfin_w': 50.00086,
#   'wavyfin_h': 59.99797,
#   'op10_l': 260.00651,
#   'op10_w': 179.99712,
#   'op10_h': 59.99797,
#   'op10_electricity': 89.18193,
#   'op10_process_time': 2.75177,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:26',
#   'pipe1_l': 30.00325,
#   'pipe1_w': 49.99809,
#   'pipe1_h': 29.99914,
#   'op20_l': 260.00651,
#   'op20_w': 179.99712,
#   'op20_h': 59.99797,
#   'op20_electricity': 95.55575,
#   'op20_process_time': 4.9831,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 30.00048,
#   'pipe2_w': 49.99853,
#   'pipe2_h': 29.99822,
#   'op30_l': 260.00651,
#   'op30_w': 179.99712,
#   'op30_h': 59.99797,
#   'op30_electricity': 92.22497,
#   'op30_process_time': 13.12712,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 29.9997,
#   'flange1_w': 80.00235,
#   'flange1_h': 39.99749,
#   'op40_l': 260.00651,
#   'op40_w': 179.99712,
#   'op40_h': 59.99797,
#   'op40_temperature': 491.79179,
#   'op40_process_time': 12.41448,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 30.00301,
#   'flange2_w': 79.99838,
#   'flange2_h': 39.99814,
#   'op50_l': 260.00651,
#   'op50_w': 179.99712,
#   'op50_h': 59.99797,
#   'op50_temperature': 505.02139,
#   'op50_process_time': 0.14854,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 260.00651,
#   'op60_w': 179.99712,
#   'op60_h': 59.99797,
#   'op60_process_time': 13.53754,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:30'},
#  {'item_key': 5,
#   'body_l': 260.00379999999996,
#   'body_w': 180.00047,
#   'body_h': 49.99771,
#   'wavyfin_l': 100.00086,
#   'wavyfin_w': 50.00345,
#   'wavyfin_h': 60.00461,
#   'op10_l': 260.00379999999996,
#   'op10_w': 180.00047,
#   'op10_h': 60.00461,
#   'op10_electricity': 90.89696,
#   'op10_process_time': 0.23508,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:26',
#   'pipe1_l': 29.99573,
#   'pipe1_w': 49.99873,
#   'pipe1_h': 30.00068,
#   'op20_l': 260.00379999999996,
#   'op20_w': 180.00047,
#   'op20_h': 60.00461,
#   'op20_electricity': 98.5059,
#   'op20_process_time': 15.81946,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 30.00058,
#   'pipe2_w': 50.0023,
#   'pipe2_h': 30.00099,
#   'op30_l': 260.00379999999996,
#   'op30_w': 180.00047,
#   'op30_h': 60.00461,
#   'op30_electricity': 93.57158,
#   'op30_process_time': 8.20789,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 30.00196,
#   'flange1_w': 79.99934,
#   'flange1_h': 40.00578,
#   'op40_l': 260.00379999999996,
#   'op40_w': 180.00047,
#   'op40_h': 60.00461,
#   'op40_temperature': 506.01657,
#   'op40_process_time': 26.85273,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 30.00036,
#   'flange2_w': 79.99931,
#   'flange2_h': 39.99707,
#   'op50_l': 260.00379999999996,
#   'op50_w': 180.00047,
#   'op50_h': 60.00461,
#   'op50_temperature': 497.20375,
#   'op50_process_time': 0.63137,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 260.00379999999996,
#   'op60_w': 180.00047,
#   'op60_h': 60.00461,
#   'op60_process_time': 2.32678,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:31'},
#  {'item_key': 6,
#   'body_l': 259.99887,
#   'body_w': 179.99793,
#   'body_h': 50.00058,
#   'wavyfin_l': 100.00143,
#   'wavyfin_w': 49.99752,
#   'wavyfin_h': 59.99983,
#   'op10_l': 259.99887,
#   'op10_w': 179.99793,
#   'op10_h': 59.99983,
#   'op10_electricity': 97.90179,
#   'op10_process_time': 2.72389,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:26',
#   'pipe1_l': 30.00261,
#   'pipe1_w': 49.99856,
#   'pipe1_h': 29.99978,
#   'op20_l': 259.99887,
#   'op20_w': 179.99793,
#   'op20_h': 59.99983,
#   'op20_electricity': 92.99458,
#   'op20_process_time': 10.35855,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 29.9976,
#   'pipe2_w': 50.00224,
#   'pipe2_h': 29.99822,
#   'op30_l': 259.99887,
#   'op30_w': 179.99793,
#   'op30_h': 59.99983,
#   'op30_electricity': 97.91481,
#   'op30_process_time': 5.0792,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 29.99818,
#   'flange1_w': 80.0072,
#   'flange1_h': 39.99902,
#   'op40_l': 259.99887,
#   'op40_w': 179.99793,
#   'op40_h': 59.99983,
#   'op40_temperature': 507.21704,
#   'op40_process_time': 5.54582,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 29.99832,
#   'flange2_w': 79.99878,
#   'flange2_h': 40.00172,
#   'op50_l': 259.99887,
#   'op50_w': 179.99793,
#   'op50_h': 59.99983,
#   'op50_temperature': 492.89745,
#   'op50_process_time': 9.35847,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 259.99887,
#   'op60_w': 179.99793,
#   'op60_h': 59.99983,
#   'op60_process_time': 17.6289,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:31'},
#  {'item_key': 7,
#   'body_l': 260.0027,
#   'body_w': 179.99931999999998,
#   'body_h': 50.00445,
#   'wavyfin_l': 100.00074,
#   'wavyfin_w': 50.0018,
#   'wavyfin_h': 60.0001,
#   'op10_l': 260.0027,
#   'op10_w': 179.99931999999998,
#   'op10_h': 60.0001,
#   'op10_electricity': 97.13044,
#   'op10_process_time': 47.24393,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:27',
#   'pipe1_l': 30.0062,
#   'pipe1_w': 49.99888,
#   'pipe1_h': 29.99933,
#   'op20_l': 260.0027,
#   'op20_w': 179.99931999999998,
#   'op20_h': 60.0001,
#   'op20_electricity': 92.88976,
#   'op20_process_time': 4.43743,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 29.99901,
#   'pipe2_w': 50.00287,
#   'pipe2_h': 29.99677,
#   'op30_l': 260.0027,
#   'op30_w': 179.99931999999998,
#   'op30_h': 60.0001,
#   'op30_electricity': 99.56749,
#   'op30_process_time': 14.94395,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 30.00167,
#   'flange1_w': 79.99752,
#   'flange1_h': 39.99966,
#   'op40_l': 260.0027,
#   'op40_w': 179.99931999999998,
#   'op40_h': 60.0001,
#   'op40_temperature': 505.16174,
#   'op40_process_time': 0.1482,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 30.0021,
#   'flange2_w': 79.99991,
#   'flange2_h': 40.00083,
#   'op50_l': 260.0027,
#   'op50_w': 179.99931999999998,
#   'op50_h': 60.0001,
#   'op50_temperature': 499.81141,
#   'op50_process_time': 25.03651,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 260.0027,
#   'op60_w': 179.99931999999998,
#   'op60_h': 60.0001,
#   'op60_process_time': 6.33,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:31'},
#  {'item_key': 8,
#   'body_l': 259.99593,
#   'body_w': 180.0047,
#   'body_h': 49.99904,
#   'wavyfin_l': 99.99991,
#   'wavyfin_w': 50.00387,
#   'wavyfin_h': 60.00024,
#   'op10_l': 259.99593,
#   'op10_w': 180.0047,
#   'op10_h': 60.00024,
#   'op10_electricity': 91.33419,
#   'op10_process_time': 11.88476,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:27',
#   'pipe1_l': 30.00231,
#   'pipe1_w': 50.00104,
#   'pipe1_h': 29.99896,
#   'op20_l': 259.99593,
#   'op20_w': 180.0047,
#   'op20_h': 60.00024,
#   'op20_electricity': 95.33697,
#   'op20_process_time': 9.67814,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:27',
#   'pipe2_l': 29.99996,
#   'pipe2_w': 50.0011,
#   'pipe2_h': 30.00332,
#   'op30_l': 259.99593,
#   'op30_w': 180.0047,
#   'op30_h': 60.00024,
#   'op30_electricity': 91.99441,
#   'op30_process_time': 4.83744,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 29.99765,
#   'flange1_w': 79.99947,
#   'flange1_h': 40.00183,
#   'op40_l': 259.99593,
#   'op40_w': 180.0047,
#   'op40_h': 60.00024,
#   'op40_temperature': 510.80928,
#   'op40_process_time': 1.71936,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 29.99943,
#   'flange2_w': 80.00133,
#   'flange2_h': 39.99917,
#   'op50_l': 259.99593,
#   'op50_w': 180.0047,
#   'op50_h': 60.00024,
#   'op50_temperature': 502.91921,
#   'op50_process_time': 5.03945,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 259.99593,
#   'op60_w': 180.0047,
#   'op60_h': 60.00024,
#   'op60_process_time': 28.74746,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:31'},
#  {'item_key': 9,
#   'body_l': 259.99847,
#   'body_w': 180.00024,
#   'body_h': 50.00082,
#   'wavyfin_l': 100.0019,
#   'wavyfin_w': 49.99385,
#   'wavyfin_h': 59.99604,
#   'op10_l': 259.99847,
#   'op10_w': 180.00024,
#   'op10_h': 59.99604,
#   'op10_electricity': 89.78891,
#   'op10_process_time': 2.86061,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-26 11:16:27',
#   'pipe1_l': 30.00004,
#   'pipe1_w': 50.001,
#   'pipe1_h': 29.99931,
#   'op20_l': 259.99847,
#   'op20_w': 180.00024,
#   'op20_h': 59.99604,
#   'op20_electricity': 92.95005,
#   'op20_process_time': 6.57255,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-26 11:16:28',
#   'pipe2_l': 30.0035,
#   'pipe2_w': 50.00069,
#   'pipe2_h': 30.00318,
#   'op30_l': 259.99847,
#   'op30_w': 180.00024,
#   'op30_h': 59.99604,
#   'op30_electricity': 90.48369,
#   'op30_process_time': 2.1545,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-26 11:16:28',
#   'flange1_l': 30.00121,
#   'flange1_w': 80.0,
#   'flange1_h': 39.99644,
#   'op40_l': 259.99847,
#   'op40_w': 180.00024,
#   'op40_h': 59.99604,
#   'op40_temperature': 489.10571,
#   'op40_process_time': 1.15526,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-26 11:16:29',
#   'flange2_l': 29.9999,
#   'flange2_w': 79.99901,
#   'flange2_h': 40.00413,
#   'op50_l': 259.99847,
#   'op50_w': 180.00024,
#   'op50_h': 59.99604,
#   'op50_temperature': 496.77346,
#   'op50_process_time': 13.71682,
#   'op50_time_stamp': '2020-09-26 11:16:30',
#   'op60_l': 259.99847,
#   'op60_w': 180.00024,
#   'op60_h': 59.99604,
#   'op60_process_time': 12.82514,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-26 11:16:31'}]

# %%
result_df = pd.DataFrame(process())
result_df = result_df.set_index('item_key')

# %%
result_df.to_excel("item_data.xlsx")

# %%
data_load = pd.read_excel("item_data.xlsx")

num_list = len(data_load)

print(num_list)
data_load
# Out:
# 10
#    item_key    body_h     body_l      body_w  flange1_h  flange1_l  flange1_w  \
# 0         0  49.99876  260.00378  179.999770   39.99955   30.00183   79.99739
# 1         1  50.00150  260.00099  179.999770   39.99868   30.00089   80.00424
# 2         2  49.99762  259.99787  180.002070   39.99979   30.00423   80.00222
# 3         3  49.99709  260.00539  180.002610   39.99903   30.00085   80.00172
# 4         4  50.00378  259.99869  179.994260   40.00208   29.99986   80.00265
# 5         5  49.99604  260.00705  180.008660   39.99788   30.00441   80.00029
# 6         6  49.99704  260.00077  179.999240   39.99945   29.99876   80.00197
# 7         7  49.99707  259.99815  180.202477   40.00170   29.99507   80.00075
# 8         8  50.00202  260.00063  179.999040   39.99887   30.00190   80.00123
# 9         9  49.99868  259.99371  180.188540   40.00103   29.99601   80.00031
#
#    flange2_h  flange2_l  flange2_w  ...      op60_w   pipe1_h   pipe1_l  \
# 0   40.00022   30.00117   79.99727  ...  179.999770  30.00109  30.00307
# 1   39.99733   29.99923   80.00117  ...  179.999770  30.00168  29.99676
# 2   39.99949   29.99843   79.99732  ...  180.002070  30.00149  30.00376
# 3   39.99960   30.00281   79.99819  ...  180.002610  30.00324  30.00238
# 4   40.00178   30.00164   80.00144  ...  179.994260  29.99851  29.99932
# 5   40.00332   29.99969   80.00319  ...  180.008660  29.99674  30.00016
# 6   40.00173   30.00069   79.99918  ...  179.999240  29.99791  29.99697
# 7   39.99721   30.00035   79.99465  ...  180.202477  30.00277  29.99781
# 8   40.00027   29.99647   80.00246  ...  179.999040  30.00202  29.99685
# 9   39.99968   29.99917   79.99866  ...  180.188540  29.99828  30.00291
#
#     pipe1_w   pipe2_h   pipe2_l   pipe2_w  wavyfin_h  wavyfin_l  wavyfin_w
# 0  50.00095  30.00207  30.00243  49.99814   59.99815  100.00039   49.99777
# 1  50.00199  30.00385  29.99982  49.99583   59.99878   99.99787   50.00191
# 2  50.00146  30.00238  30.00067  50.00057   59.99750  100.00012   49.99916
# 3  50.00454  30.00232  29.99998  49.99842   60.00020  100.00164   49.99735
# 4  49.99316  29.99925  30.00028  50.00198   59.99782  100.00132   49.99706
# 5  50.00231  30.00019  30.00018  50.00476   60.00095  100.00269   49.99751
# 6  50.00013  30.00476  30.00244  49.99850   59.99734  100.00272   49.99943
# 7  49.99880  29.99934  29.99902  49.99908   59.99987  100.00053   49.99883
# 8  50.00231  29.99617  29.99674  49.99577   60.00204  100.00180   50.00359
# 9  49.99967  30.00130  30.00015  49.99971   60.00073   99.99935   50.00130
#
# [10 rows x 59 columns]
