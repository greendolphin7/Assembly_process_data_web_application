# %% [markdown]
# # 공정 데이터 생성

# %%
import numpy as np
import pandas as pd
import time
from time import sleep
from datetime import datetime

# %%
time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
print(time_stamp)

# sleep을 실행시킬 때는 나두고 time_stamp 저장할 때 바꾸는 방법 고려
# Out:
# 2020-09-24 22:55:21

# %%
def process():
    item_data = []
    std = 0.0025 # 표준편차
    amount = 10 # 생성 아이템 갯수
    
    makespan = 0 # 총처리 시간
    
    speed = 0.01 # 배수 적어지면 적어질수록 빨라짐
    
    ############################################################################
    # 처리시간 생성
    op10_process_time = np.random.exponential(10, amount)
    op10_process_time = op10_process_time.round(5)
    
    op20_process_time = np.random.exponential(10, amount)
    op20_process_time = op20_process_time.round(5)
    
    op30_process_time = np.random.exponential(10, amount)
    op30_process_time = op30_process_time.round(5)
    
    op40_process_time = np.random.exponential(10, amount)
    op40_process_time = op40_process_time.round(5)
    
    op50_process_time = np.random.exponential(10, amount)
    op50_process_time = op50_process_time.round(5)
    
    op60_process_time = np.random.exponential(10, amount)
    op60_process_time = op60_process_time.round(5)
    
    ############################################################################
    # op10
    body_l = np.random.normal(200,std, amount)
    body_l = body_l.round(5)
    body_w = np.random.normal(100,std, amount)
    body_w = body_w.round(5)
    body_h = np.random.normal(50,std, amount)
    body_h = body_h.round(5)
    
    wavyfin_l = np.random.normal(100,std, amount)
    wavyfin_l = wavyfin_l.round(5)
    wavyfin_w = np.random.normal(50,std, amount)
    wavyfin_w = wavyfin_w.round(5)
    wavyfin_h = np.random.normal(60,std, amount)
    wavyfin_h = wavyfin_h.round(5)
    
    op10_electricity = np.random.uniform(89, 100, amount)
    op10_electricity = op10_electricity.round(5)
    
    op10_l = body_l
    op10_w = body_w
    op10_h = wavyfin_h
    
    op10_time_stamp = []
    
    for process in range(amount):
        
        op10_l[process] = body_l[process]
        op10_w[process] = body_w[process]
        op10_h[process] = wavyfin_h[process]
    
        time.sleep(op10_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op10_time_stamp.append(time_stamp)
    
    op10_test = []
    
    for test in range(amount):
    
        if (op10_l[test] < 199.99) or (op10_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op10_w[test] < 99.99) or (op10_w[test] > 100.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op10_h[test] < 59.99) or (op10_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op10_test.append(0)
        else:
            op10_test.append(1)
    
    ############################################################################
    # op20
    pipe1_l = np.random.normal(30,std, amount)
    pipe1_l = pipe1_l.round(5)
    pipe1_w = np.random.normal(50,std, amount)
    pipe1_w = pipe1_w.round(5)
    pipe1_h = np.random.normal(30,std, amount)
    pipe1_h = pipe1_h.round(5)
    
    op20_electricity = np.random.uniform(89, 100, amount)
    op20_electricity = op20_electricity.round(5)
    
    op20_l = op10_l
    op20_w = body_w
    op20_h = op10_h
    
    op20_time_stamp = []
    
    for process in range(amount):
        
        op20_l[process] = op10_l[process]
        op20_w[process] = body_w[process]
        op20_h[process] = op10_h[process]
    
        time.sleep(op20_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op20_time_stamp.append(time_stamp)
    
    for item_20 in range(amount):
        
        if op20_electricity[item_20] < 90:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - op20_electricity[item_20] * 0.11
        else:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - 10
            
    op20_test = []
    
    for test in range(amount):
    
        if (op20_l[test] < 199.99) or (op20_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op20_w[test] < 139.99) or (op20_w[test] > 140.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op20_h[test] < 59.99) or (op20_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op20_test.append(0)
        else:
            op20_test.append(1)
    
    ############################################################################
    
    pipe2_l = np.random.normal(30,std, amount)
    pipe2_l = pipe2_l.round(5)
    pipe2_w = np.random.normal(50,std, amount)
    pipe2_w = pipe2_w.round(5)
    pipe2_h = np.random.normal(30,std, amount)
    pipe2_h = pipe2_h.round(5)
    
    op30_electricity = np.random.uniform(89, 100, amount)
    op30_electricity = op30_electricity.round(5)
    
    op30_l = op20_l
    op30_w = op20_w
    op30_h = op20_h
    
    op30_time_stamp = []
    
    for process in range(amount):
        
        op30_l[process] = op20_l[process]
        op30_w[process] = op20_w[process]
        op30_h[process] = op20_h[process]
    
        time.sleep(op30_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op30_time_stamp.append(time_stamp)
    
    for item_30 in range(amount):
        
        if op30_electricity[item_30] < 90:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - op30_electricity[item_30] * 0.11
        else:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - 10

    op30_test = []
    
    for test in range(amount):
    
        if (op30_l[test] < 199.99) or (op30_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op30_w[test] < 179.99) or (op30_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op30_h[test] < 59.99) or (op30_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op30_test.append(0)
        else:
            op30_test.append(1)
    
    ############################################################################
    
    flange1_l = np.random.normal(30,std, amount)
    flange1_l = flange1_l.round(5)
    flange1_w = np.random.normal(80,std, amount)
    flange1_w = flange1_w.round(5)
    flange1_h = np.random.normal(40,std, amount)
    flange1_h = flange1_h.round(5)
    
    op40_temperature = np.random.uniform(489, 511, amount)
    op40_temperature = op40_temperature.round(5)
    
    op40_l = op30_l
    op40_w = op30_w
    op40_h = op30_h
    
    op40_time_stamp = []
    
    for process in range(amount):
        
        op40_l[process] = op30_l[process]
        op40_w[process] = op30_w[process]
        op40_h[process] = op30_h[process]
    
        time.sleep(op40_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op40_time_stamp.append(time_stamp)
    
    for item_40 in range(amount):
        
        if 489 < op40_temperature[item_40] < 511:
            op40_l[item_40] = op30_l[item_40] + flange1_l[item_40]
        else:
            op40_l[item_40] = 0

    op40_test = []
    
    for test in range(amount):
    
        if (op40_l[test] < 229.99) or (op40_l[test] > 230.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op40_w[test] < 179.99) or (op40_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op40_h[test] < 59.99) or (op40_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op40_test.append(0)
        else:
            op40_test.append(1)
    
    ############################################################################
    
    flange2_l = np.random.normal(30,std, amount)
    flange2_l = flange2_l.round(5)
    flange2_w = np.random.normal(80,std, amount)
    flange2_w = flange2_w.round(5)
    flange2_h = np.random.normal(40,std, amount)
    flange2_h = flange2_h.round(5)
    
    op50_temperature = np.random.uniform(489, 511, amount)
    op50_temperature = op50_temperature.round(5)
    
    op50_l = op40_l
    op50_w = op40_w
    op50_h = op40_h
    
    op50_time_stamp = []
    
    for process in range(amount):
        
        op50_l[process] = op40_l[process]
        op50_w[process] = op40_w[process]
        op50_h[process] = op40_h[process]
    
        time.sleep(op50_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op50_time_stamp.append(time_stamp)
    
    for item_50 in range(amount):
        
        if 489 < op50_temperature[item_50] < 511:
            op50_l[item_50] = op40_l[item_50] + flange2_l[item_50]
        else:
            op50_l[item_50] = 0

    
    ############################################################################
    
    op60_time_stamp = []
    
    op60_l = op50_l
    op60_w = op50_w
    op60_h = op50_h
    
    for process in range(amount):
        
        op60_l[process] = op50_l[process]
        op60_w[process] = op50_w[process]
        op60_h[process] = op50_h[process]
    
        time.sleep(op60_process_time[process] * speed)
        time_stamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        op60_time_stamp.append(time_stamp)
        
    op60_test = []
    
    for test in range(amount):
    
        if (op50_l[test] < 259.99) or (op50_l[test] > 260.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op50_w[test] < 179.99) or (op50_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op50_h[test] < 59.99) or (op50_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op60_test.append(0)
        else:
            op60_test.append(1)
            
    ############################################################################
    
    for i in range(amount):
        item = {}
        item['item_key'] = i
        item['body_l'] = body_l[i]
        item['body_w'] = body_w[i]
        item['body_h'] = body_h[i]
        
        item['wavyfin_l'] = wavyfin_l[i]
        item['wavyfin_w'] = wavyfin_w[i]
        item['wavyfin_h'] = wavyfin_h[i]
        
        item['op10_l'] = body_l[i]
        item['op10_w'] = body_w[i]
        item['op10_h'] = wavyfin_h[i]
        item['op10_electricity'] = op10_electricity[i]
        item['op10_process_time'] = op10_process_time[i]
        item['op10_test'] = op10_test[i]
        item['op10_time_stamp'] = op10_time_stamp[i]

        item['pipe1_l'] = pipe1_l[i]
        item['pipe1_w'] = pipe1_w[i]
        item['pipe1_h'] = pipe1_h[i]
        
        item['op20_l'] = op20_l[i]            
        item['op20_w'] = op20_w[i]
        item['op20_h'] = op20_h[i]
        item['op20_electricity'] = op20_electricity[i]
        item['op20_process_time'] = op20_process_time[i]
        item['op20_test'] = op20_test[i]
        item['op20_time_stamp'] = op20_time_stamp[i]
        
        item['pipe2_l'] = pipe2_l[i]
        item['pipe2_w'] = pipe2_w[i]
        item['pipe2_h'] = pipe2_h[i]
        
        item['op30_l'] = op30_l[i]            
        item['op30_w'] = op30_w[i]
        item['op30_h'] = op30_h[i]
        item['op30_electricity'] = op30_electricity[i]
        item['op30_process_time'] = op30_process_time[i]
        item['op30_test'] = op30_test[i]
        item['op30_time_stamp'] = op30_time_stamp[i]
        
        item['flange1_l'] = flange1_l[i]
        item['flange1_w'] = flange1_w[i]
        item['flange1_h'] = flange1_h[i]
        
        item['op40_l'] = op40_l[i]            
        item['op40_w'] = op40_w[i]
        item['op40_h'] = op40_h[i]
        item['op40_temperature'] = op40_temperature[i]
        item['op40_process_time'] = op40_process_time[i]
        item['op40_test'] = op40_test[i]
        item['op40_time_stamp'] = op40_time_stamp[i]
        
        item['flange2_l'] = flange2_l[i]
        item['flange2_w'] = flange2_w[i]
        item['flange2_h'] = flange2_h[i]
        
        item['op50_l'] = op50_l[i]            
        item['op50_w'] = op50_w[i]
        item['op50_h'] = op50_h[i]
        item['op50_temperature'] = op50_temperature[i]
        item['op50_process_time'] = op50_process_time[i]
        item['op50_time_stamp'] = op50_time_stamp[i]
        
        item['op60_l'] = op60_l[i]            
        item['op60_w'] = op60_w[i]
        item['op60_h'] = op60_h[i]
        item['op60_process_time'] = op60_process_time[i]
        item['op60_test'] = op60_test[i]
        item['op60_time_stamp'] = op60_time_stamp[i]
        
        item_data.append(item)
    
    return item_data

# %%
process()
# Out:
# [{'item_key': 0,
#   'body_l': 259.99242,
#   'body_w': 180.00539,
#   'body_h': 50.0019,
#   'wavyfin_l': 100.00105,
#   'wavyfin_w': 50.00102,
#   'wavyfin_h': 59.99803,
#   'op10_l': 259.99242,
#   'op10_w': 180.00539,
#   'op10_h': 59.99803,
#   'op10_electricity': 94.59749,
#   'op10_process_time': 9.18853,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:08',
#   'pipe1_l': 29.99525,
#   'pipe1_w': 50.00091,
#   'pipe1_h': 30.00208,
#   'op20_l': 259.99242,
#   'op20_w': 180.00539,
#   'op20_h': 59.99803,
#   'op20_electricity': 91.84733,
#   'op20_process_time': 1.13865,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:09',
#   'pipe2_l': 29.99981,
#   'pipe2_w': 49.99918,
#   'pipe2_h': 29.99571,
#   'op30_l': 259.99242,
#   'op30_w': 180.00539,
#   'op30_h': 59.99803,
#   'op30_electricity': 97.165,
#   'op30_process_time': 9.67975,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:10',
#   'flange1_l': 30.00161,
#   'flange1_w': 79.99793,
#   'flange1_h': 39.99949,
#   'op40_l': 259.99242,
#   'op40_w': 180.00539,
#   'op40_h': 59.99803,
#   'op40_temperature': 497.89872,
#   'op40_process_time': 10.13973,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:11',
#   'flange2_l': 29.99555,
#   'flange2_w': 80.00362,
#   'flange2_h': 39.99533,
#   'op50_l': 259.99242,
#   'op50_w': 180.00539,
#   'op50_h': 59.99803,
#   'op50_temperature': 499.20904,
#   'op50_process_time': 3.91853,
#   'op50_time_stamp': '2020-09-24 23:50:12',
#   'op60_l': 259.99242,
#   'op60_w': 180.00539,
#   'op60_h': 59.99803,
#   'op60_process_time': 2.65542,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:13'},
#  {'item_key': 1,
#   'body_l': 259.9948,
#   'body_w': 179.98951000000002,
#   'body_h': 50.00034,
#   'wavyfin_l': 100.0033,
#   'wavyfin_w': 50.00145,
#   'wavyfin_h': 59.99542,
#   'op10_l': 259.9948,
#   'op10_w': 179.98951000000002,
#   'op10_h': 59.99542,
#   'op10_electricity': 99.03869,
#   'op10_process_time': 1.88299,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:08',
#   'pipe1_l': 30.00157,
#   'pipe1_w': 49.99786,
#   'pipe1_h': 29.99996,
#   'op20_l': 259.9948,
#   'op20_w': 179.98951000000002,
#   'op20_h': 59.99542,
#   'op20_electricity': 95.88654,
#   'op20_process_time': 5.47686,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:09',
#   'pipe2_l': 29.99896,
#   'pipe2_w': 49.99393,
#   'pipe2_h': 30.00857,
#   'op30_l': 259.9948,
#   'op30_w': 179.98951000000002,
#   'op30_h': 59.99542,
#   'op30_electricity': 93.78024,
#   'op30_process_time': 1.39791,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:10',
#   'flange1_l': 29.99775,
#   'flange1_w': 79.99943,
#   'flange1_h': 39.99502,
#   'op40_l': 259.9948,
#   'op40_w': 179.98951000000002,
#   'op40_h': 59.99542,
#   'op40_temperature': 509.88915,
#   'op40_process_time': 13.82967,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:11',
#   'flange2_l': 29.99705,
#   'flange2_w': 80.00195,
#   'flange2_h': 40.00222,
#   'op50_l': 259.9948,
#   'op50_w': 179.98951000000002,
#   'op50_h': 59.99542,
#   'op50_temperature': 499.32702,
#   'op50_process_time': 13.46286,
#   'op50_time_stamp': '2020-09-24 23:50:12',
#   'op60_l': 259.9948,
#   'op60_w': 179.98951000000002,
#   'op60_h': 59.99542,
#   'op60_process_time': 0.26817,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:13'},
#  {'item_key': 2,
#   'body_l': 259.99262999999996,
#   'body_w': 180.00455,
#   'body_h': 49.99983,
#   'wavyfin_l': 99.99929,
#   'wavyfin_w': 50.00326,
#   'wavyfin_h': 60.00315,
#   'op10_l': 259.99262999999996,
#   'op10_w': 180.00455,
#   'op10_h': 60.00315,
#   'op10_electricity': 99.34952,
#   'op10_process_time': 24.41238,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 29.99913,
#   'pipe1_w': 50.0017,
#   'pipe1_h': 30.00204,
#   'op20_l': 259.99262999999996,
#   'op20_w': 180.00455,
#   'op20_h': 60.00315,
#   'op20_electricity': 96.79811,
#   'op20_process_time': 9.22265,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 29.99821,
#   'pipe2_w': 50.00193,
#   'pipe2_h': 30.00181,
#   'op30_l': 259.99262999999996,
#   'op30_w': 180.00455,
#   'op30_h': 60.00315,
#   'op30_electricity': 92.25501,
#   'op30_process_time': 28.11365,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 29.99647,
#   'flange1_w': 80.00431,
#   'flange1_h': 39.99744,
#   'op40_l': 259.99262999999996,
#   'op40_w': 180.00455,
#   'op40_h': 60.00315,
#   'op40_temperature': 499.91513,
#   'op40_process_time': 1.88255,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:11',
#   'flange2_l': 29.99655,
#   'flange2_w': 79.99745,
#   'flange2_h': 39.99881,
#   'op50_l': 259.99262999999996,
#   'op50_w': 180.00455,
#   'op50_h': 60.00315,
#   'op50_temperature': 505.17198,
#   'op50_process_time': 0.33285,
#   'op50_time_stamp': '2020-09-24 23:50:12',
#   'op60_l': 259.99262999999996,
#   'op60_w': 180.00455,
#   'op60_h': 60.00315,
#   'op60_process_time': 47.55456,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'},
#  {'item_key': 3,
#   'body_l': 259.9964,
#   'body_w': 180.17527029999997,
#   'body_h': 50.00304,
#   'wavyfin_l': 100.00079,
#   'wavyfin_w': 49.99695,
#   'wavyfin_h': 60.00387,
#   'op10_l': 259.9964,
#   'op10_w': 180.17527029999997,
#   'op10_h': 60.00387,
#   'op10_electricity': 99.54592,
#   'op10_process_time': 10.81015,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 30.00034,
#   'pipe1_w': 50.00465,
#   'pipe1_h': 30.00294,
#   'op20_l': 259.9964,
#   'op20_w': 180.17527029999997,
#   'op20_h': 60.00387,
#   'op20_electricity': 94.92643,
#   'op20_process_time': 3.42132,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 29.99872,
#   'pipe2_w': 50.00075,
#   'pipe2_h': 29.99811,
#   'op30_l': 259.9964,
#   'op30_w': 180.17527029999997,
#   'op30_h': 60.00387,
#   'op30_electricity': 89.34327,
#   'op30_process_time': 4.84075,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 29.99829,
#   'flange1_w': 79.9969,
#   'flange1_h': 39.99588,
#   'op40_l': 259.9964,
#   'op40_w': 180.17527029999997,
#   'op40_h': 60.00387,
#   'op40_temperature': 499.85013,
#   'op40_process_time': 16.53907,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:11',
#   'flange2_l': 29.99943,
#   'flange2_w': 79.99546,
#   'flange2_h': 39.99988,
#   'op50_l': 259.9964,
#   'op50_w': 180.17527029999997,
#   'op50_h': 60.00387,
#   'op50_temperature': 503.40991,
#   'op50_process_time': 17.02733,
#   'op50_time_stamp': '2020-09-24 23:50:12',
#   'op60_l': 259.9964,
#   'op60_w': 180.17527029999997,
#   'op60_h': 60.00387,
#   'op60_process_time': 1.90511,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'},
#  {'item_key': 4,
#   'body_l': 260.00848,
#   'body_w': 179.99909,
#   'body_h': 50.00219,
#   'wavyfin_l': 100.00211,
#   'wavyfin_w': 49.99904,
#   'wavyfin_h': 59.9991,
#   'op10_l': 260.00848,
#   'op10_w': 179.99909,
#   'op10_h': 59.9991,
#   'op10_electricity': 93.65727,
#   'op10_process_time': 3.88052,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 29.99612,
#   'pipe1_w': 49.99904,
#   'pipe1_h': 29.99989,
#   'op20_l': 260.00848,
#   'op20_w': 179.99909,
#   'op20_h': 59.9991,
#   'op20_electricity': 91.146,
#   'op20_process_time': 0.9429,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 30.00569,
#   'pipe2_w': 49.99657,
#   'pipe2_h': 30.00122,
#   'op30_l': 260.00848,
#   'op30_w': 179.99909,
#   'op30_h': 59.9991,
#   'op30_electricity': 98.68063,
#   'op30_process_time': 14.85589,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 30.00597,
#   'flange1_w': 79.99971,
#   'flange1_h': 39.99887,
#   'op40_l': 260.00848,
#   'op40_w': 179.99909,
#   'op40_h': 59.9991,
#   'op40_temperature': 495.4606,
#   'op40_process_time': 2.72063,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:12',
#   'flange2_l': 30.00122,
#   'flange2_w': 80.00288,
#   'flange2_h': 39.99665,
#   'op50_l': 260.00848,
#   'op50_w': 179.99909,
#   'op50_h': 59.9991,
#   'op50_temperature': 509.14799,
#   'op50_process_time': 3.60307,
#   'op50_time_stamp': '2020-09-24 23:50:12',
#   'op60_l': 260.00848,
#   'op60_w': 179.99909,
#   'op60_h': 59.9991,
#   'op60_process_time': 11.24648,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'},
#  {'item_key': 5,
#   'body_l': 260.00153,
#   'body_w': 179.99630000000002,
#   'body_h': 49.99861,
#   'wavyfin_l': 100.00057,
#   'wavyfin_w': 49.99987,
#   'wavyfin_h': 60.00091,
#   'op10_l': 260.00153,
#   'op10_w': 179.99630000000002,
#   'op10_h': 60.00091,
#   'op10_electricity': 92.85489,
#   'op10_process_time': 3.47501,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 30.00331,
#   'pipe1_w': 49.9987,
#   'pipe1_h': 30.00007,
#   'op20_l': 260.00153,
#   'op20_w': 179.99630000000002,
#   'op20_h': 60.00091,
#   'op20_electricity': 98.59313,
#   'op20_process_time': 18.23469,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 29.99561,
#   'pipe2_w': 49.99763,
#   'pipe2_h': 29.99876,
#   'op30_l': 260.00153,
#   'op30_w': 179.99630000000002,
#   'op30_h': 60.00091,
#   'op30_electricity': 91.33975,
#   'op30_process_time': 9.06747,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 30.0001,
#   'flange1_w': 79.99786,
#   'flange1_h': 39.99831,
#   'op40_l': 260.00153,
#   'op40_w': 179.99630000000002,
#   'op40_h': 60.00091,
#   'op40_temperature': 496.50641,
#   'op40_process_time': 14.55893,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:12',
#   'flange2_l': 30.00193,
#   'flange2_w': 80.00248,
#   'flange2_h': 39.99991,
#   'op50_l': 260.00153,
#   'op50_w': 179.99630000000002,
#   'op50_h': 60.00091,
#   'op50_temperature': 504.21469,
#   'op50_process_time': 19.17203,
#   'op50_time_stamp': '2020-09-24 23:50:13',
#   'op60_l': 260.00153,
#   'op60_w': 179.99630000000002,
#   'op60_h': 60.00091,
#   'op60_process_time': 15.99646,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'},
#  {'item_key': 6,
#   'body_l': 260.00053,
#   'body_w': 179.99499,
#   'body_h': 49.99975,
#   'wavyfin_l': 99.99952,
#   'wavyfin_w': 49.99761,
#   'wavyfin_h': 59.99818,
#   'op10_l': 260.00053,
#   'op10_w': 179.99499,
#   'op10_h': 59.99818,
#   'op10_electricity': 98.82286,
#   'op10_process_time': 12.54054,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 29.99972,
#   'pipe1_w': 49.99833,
#   'pipe1_h': 29.99876,
#   'op20_l': 260.00053,
#   'op20_w': 179.99499,
#   'op20_h': 59.99818,
#   'op20_electricity': 97.31567,
#   'op20_process_time': 19.09046,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 30.00055,
#   'pipe2_w': 49.9997,
#   'pipe2_h': 30.00185,
#   'op30_l': 260.00053,
#   'op30_w': 179.99499,
#   'op30_h': 59.99818,
#   'op30_electricity': 90.0658,
#   'op30_process_time': 0.63702,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 29.99943,
#   'flange1_w': 79.998,
#   'flange1_h': 40.00225,
#   'op40_l': 260.00053,
#   'op40_w': 179.99499,
#   'op40_h': 59.99818,
#   'op40_temperature': 509.98954,
#   'op40_process_time': 2.07261,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:12',
#   'flange2_l': 29.99963,
#   'flange2_w': 80.00535,
#   'flange2_h': 40.00079,
#   'op50_l': 260.00053,
#   'op50_w': 179.99499,
#   'op50_h': 59.99818,
#   'op50_temperature': 502.04906,
#   'op50_process_time': 5.82212,
#   'op50_time_stamp': '2020-09-24 23:50:13',
#   'op60_l': 260.00053,
#   'op60_w': 179.99499,
#   'op60_h': 59.99818,
#   'op60_process_time': 0.57643,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'},
#  {'item_key': 7,
#   'body_l': 259.99937,
#   'body_w': 180.00405,
#   'body_h': 50.00018,
#   'wavyfin_l': 100.00012,
#   'wavyfin_w': 50.00122,
#   'wavyfin_h': 60.00083,
#   'op10_l': 259.99937,
#   'op10_w': 180.00405,
#   'op10_h': 60.00083,
#   'op10_electricity': 97.09014,
#   'op10_process_time': 2.56453,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 30.00188,
#   'pipe1_w': 50.00259,
#   'pipe1_h': 29.99842,
#   'op20_l': 259.99937,
#   'op20_w': 180.00405,
#   'op20_h': 60.00083,
#   'op20_electricity': 95.21708,
#   'op20_process_time': 1.47974,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 29.99717,
#   'pipe2_w': 49.99795,
#   'pipe2_h': 29.99846,
#   'op30_l': 259.99937,
#   'op30_w': 180.00405,
#   'op30_h': 60.00083,
#   'op30_electricity': 91.91826,
#   'op30_process_time': 7.47545,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 29.99953,
#   'flange1_w': 79.99954,
#   'flange1_h': 39.99564,
#   'op40_l': 259.99937,
#   'op40_w': 180.00405,
#   'op40_h': 60.00083,
#   'op40_temperature': 508.73396,
#   'op40_process_time': 13.90911,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:12',
#   'flange2_l': 29.99688,
#   'flange2_w': 79.99875,
#   'flange2_h': 39.99995,
#   'op50_l': 259.99937,
#   'op50_w': 180.00405,
#   'op50_h': 60.00083,
#   'op50_temperature': 499.31372,
#   'op50_process_time': 11.92841,
#   'op50_time_stamp': '2020-09-24 23:50:13',
#   'op60_l': 259.99937,
#   'op60_w': 180.00405,
#   'op60_h': 60.00083,
#   'op60_process_time': 7.41337,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'},
#  {'item_key': 8,
#   'body_l': 260.00122999999996,
#   'body_w': 180.00303,
#   'body_h': 50.00235,
#   'wavyfin_l': 99.99599,
#   'wavyfin_w': 49.99867,
#   'wavyfin_h': 59.99633,
#   'op10_l': 260.00122999999996,
#   'op10_w': 180.00303,
#   'op10_h': 59.99633,
#   'op10_electricity': 93.3654,
#   'op10_process_time': 14.68651,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 30.00197,
#   'pipe1_w': 50.00173,
#   'pipe1_h': 29.99759,
#   'op20_l': 260.00122999999996,
#   'op20_w': 180.00303,
#   'op20_h': 59.99633,
#   'op20_electricity': 96.39199,
#   'op20_process_time': 22.65511,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 29.99818,
#   'pipe2_w': 50.00384,
#   'pipe2_h': 29.9991,
#   'op30_l': 260.00122999999996,
#   'op30_w': 180.00303,
#   'op30_h': 59.99633,
#   'op30_electricity': 98.13744,
#   'op30_process_time': 3.56833,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 29.99777,
#   'flange1_w': 80.00091,
#   'flange1_h': 39.99454,
#   'op40_l': 260.00122999999996,
#   'op40_w': 180.00303,
#   'op40_h': 59.99633,
#   'op40_temperature': 498.53931,
#   'op40_process_time': 20.3091,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:12',
#   'flange2_l': 30.00243,
#   'flange2_w': 79.9984,
#   'flange2_h': 39.99792,
#   'op50_l': 260.00122999999996,
#   'op50_w': 180.00303,
#   'op50_h': 59.99633,
#   'op50_temperature': 508.83314,
#   'op50_process_time': 27.05346,
#   'op50_time_stamp': '2020-09-24 23:50:13',
#   'op60_l': 260.00122999999996,
#   'op60_w': 180.00303,
#   'op60_h': 59.99633,
#   'op60_process_time': 4.02928,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'},
#  {'item_key': 9,
#   'body_l': 259.99939,
#   'body_w': 179.9944,
#   'body_h': 49.9996,
#   'wavyfin_l': 100.00236,
#   'wavyfin_w': 50.00143,
#   'wavyfin_h': 59.99651,
#   'op10_l': 259.99939,
#   'op10_w': 179.9944,
#   'op10_h': 59.99651,
#   'op10_electricity': 91.61501,
#   'op10_process_time': 12.62837,
#   'op10_test': 0,
#   'op10_time_stamp': '2020-09-24 23:50:09',
#   'pipe1_l': 30.00145,
#   'pipe1_w': 49.99804,
#   'pipe1_h': 29.99835,
#   'op20_l': 259.99939,
#   'op20_w': 179.9944,
#   'op20_h': 59.99651,
#   'op20_electricity': 96.20759,
#   'op20_process_time': 4.03063,
#   'op20_test': 0,
#   'op20_time_stamp': '2020-09-24 23:50:10',
#   'pipe2_l': 30.00018,
#   'pipe2_w': 49.99972,
#   'pipe2_h': 30.00196,
#   'op30_l': 259.99939,
#   'op30_w': 179.9944,
#   'op30_h': 59.99651,
#   'op30_electricity': 92.8208,
#   'op30_process_time': 4.20485,
#   'op30_test': 0,
#   'op30_time_stamp': '2020-09-24 23:50:11',
#   'flange1_l': 29.99911,
#   'flange1_w': 80.00057,
#   'flange1_h': 40.00055,
#   'op40_l': 259.99939,
#   'op40_w': 179.9944,
#   'op40_h': 59.99651,
#   'op40_temperature': 498.54757,
#   'op40_process_time': 4.78692,
#   'op40_test': 0,
#   'op40_time_stamp': '2020-09-24 23:50:12',
#   'flange2_l': 29.99916,
#   'flange2_w': 79.99775,
#   'flange2_h': 40.00384,
#   'op50_l': 259.99939,
#   'op50_w': 179.9944,
#   'op50_h': 59.99651,
#   'op50_temperature': 510.00191,
#   'op50_process_time': 13.6457,
#   'op50_time_stamp': '2020-09-24 23:50:13',
#   'op60_l': 259.99939,
#   'op60_w': 179.9944,
#   'op60_h': 59.99651,
#   'op60_process_time': 5.0195,
#   'op60_test': 0,
#   'op60_time_stamp': '2020-09-24 23:50:14'}]

# %%
result_df = pd.DataFrame(process())
result_df = result_df.set_index('item_key')

# %%
result_df.to_excel("item_data.xlsx")

# %%
data_load = pd.read_excel("item_data.xlsx")

num_list = len(data_load)

print(num_list)
data_load
# Out:
# 10
#    item_key    body_h     body_l      body_w  flange1_h  flange1_l  flange1_w  \
# 0         0  50.00043  259.99883  180.003050   39.99791   29.99911   79.99690
# 1         1  49.99384  259.99356  179.996260   39.99957   29.99651   79.99849
# 2         2  49.99831  259.99879  179.998940   40.00064   30.00069   79.99892
# 3         3  50.00309  259.99932  180.155005   39.99990   30.00178   79.99580
# 4         4  49.99819  259.99568  180.000150   40.00104   29.99713   79.99817
# 5         5  49.99897  260.00116  179.997860   39.99925   29.99901   80.00075
# 6         6  50.00616  259.99213  179.997190   39.99746   29.99690   79.99827
# 7         7  49.99326  260.00130  179.998010   40.00139   30.00080   80.00019
# 8         8  50.00173  260.00134  180.000530   40.00012   30.00274   79.99884
# 9         9  50.00135  259.99544  180.004040   39.99590   29.99735   79.99511
#
#    flange2_h  flange2_l  flange2_w  ...      op60_w   pipe1_h   pipe1_l  \
# 0   40.00209   29.99663   79.99441  ...  180.003050  30.00020  30.00174
# 1   39.99588   29.99577   80.00287  ...  179.996260  30.00211  30.00360
# 2   40.00007   29.99897   79.99641  ...  179.998940  29.99791  29.99970
# 3   39.99817   29.99874   79.99868  ...  180.155005  29.99417  29.99744
# 4   39.99889   29.99821   79.99662  ...  180.000150  30.00058  29.99869
# 5   40.00069   30.00004   80.00002  ...  179.997860  29.99737  29.99891
# 6   40.00518   29.99877   79.99625  ...  179.997190  29.99868  29.99733
# 7   40.00222   29.99875   79.99960  ...  179.998010  29.99943  30.00249
# 8   39.99595   29.99759   79.99951  ...  180.000530  30.00235  30.00605
# 9   40.00182   29.99732   80.00394  ...  180.004040  30.00135  30.00205
#
#     pipe1_w   pipe2_h   pipe2_l   pipe2_w  wavyfin_h  wavyfin_l  wavyfin_w
# 0  50.00190  29.99981  29.99650  50.00167   59.99906  100.00199   50.00261
# 1  49.99803  29.99701  29.99923  50.00113   59.99976  100.00067   50.00170
# 2  49.99770  30.00094  29.99944  50.00007   60.00392  100.00127   50.00036
# 3  49.99707  30.00308  30.00312  50.00133   60.00525  100.00231   49.99753
# 4  50.00190  29.99726  29.99904  50.00078   60.00002  100.00575   50.00175
# 5  50.00102  30.00002  29.99784  50.00186   60.00442   99.99424   50.00312
# 6  49.99697  29.99588  29.99654  49.99988   59.99993  100.00349   50.00167
# 7  50.00175  29.99662  29.99494  49.99984   59.99975  100.00214   49.99809
# 8  50.00450  30.00314  30.00051  49.99772   60.00008  100.00675   49.99915
# 9  50.00003  30.00570  30.00011  50.00023   59.99982  100.00118   50.00393
#
# [10 rows x 59 columns]
