# %% [markdown]
# # 공정 데이터 생성

# %%
import numpy as np
import pandas as pd
import time
from time import sleep

# %%
def process():
    item_data = []
    std = 0.0025
    amount = 10
    
    ############################################################################
    
    op10_process_time = np.random.exponential(10, amount)
    op10_process_time = op10_process_time.round(5)
    
    op20_process_time = np.random.exponential(10, amount)
    op20_process_time = op20_process_time.round(5)
    
    op30_process_time = np.random.exponential(10, amount)
    op30_process_time = op30_process_time.round(5)
    
    op40_process_time = np.random.exponential(10, amount)
    op40_process_time = op40_process_time.round(5)
    
    op50_process_time = np.random.exponential(10, amount)
    op50_process_time = op50_process_time.round(5)
    
    ############################################################################
    
    body_l = np.random.normal(200,std, amount)
    body_l = body_l.round(5)
    body_w = np.random.normal(100,std, amount)
    body_w = body_w.round(5)
    body_h = np.random.normal(50,std, amount)
    body_h = body_h.round(5)
    
    wavyfin_l = np.random.normal(100,std, amount)
    wavyfin_l = wavyfin_l.round(5)
    wavyfin_w = np.random.normal(50,std, amount)
    wavyfin_w = wavyfin_w.round(5)
    wavyfin_h = np.random.normal(60,std, amount)
    wavyfin_h = wavyfin_h.round(5)
    
    op10_electricity = np.random.uniform(89, 100, amount)
    op10_electricity = op10_electricity.round(5)
    
    op10_l = body_l
    op10_w = body_w
    op10_h = wavyfin_h
    
    op10_test = []
    
    for test in range(amount):
    
        if (op10_l[test] < 199.99) or (op10_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op10_w[test] < 99.99) or (op10_w[test] > 100.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op10_h[test] < 59.99) or (op10_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op10_test.append(0)
        else:
            op10_test.append(1)
    
    ############################################################################
    
    pipe1_l = np.random.normal(30,std, amount)
    pipe1_l = pipe1_l.round(5)
    pipe1_w = np.random.normal(50,std, amount)
    pipe1_w = pipe1_w.round(5)
    pipe1_h = np.random.normal(30,std, amount)
    pipe1_h = pipe1_h.round(5)
    
    op20_electricity = np.random.uniform(89, 100, amount)
    op20_electricity = op20_electricity.round(5)
    
    op20_l = op10_l
    op20_w = body_w
    
    for item_20 in range(amount):
        
        if op20_electricity[item_20] < 90:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - op20_electricity[item_20] * 0.11
        else:
            op20_w[item_20] = body_w[item_20] + pipe1_w[item_20] - 10
            
    op20_h = op10_h
    
    op20_test = []
    
    for test in range(amount):
    
        if (op20_l[test] < 199.99) or (op20_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op20_w[test] < 139.99) or (op20_w[test] > 140.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op20_h[test] < 59.99) or (op20_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op20_test.append(0)
        else:
            op20_test.append(1)
    
    ############################################################################
    
    pipe2_l = np.random.normal(30,std, amount)
    pipe2_l = pipe2_l.round(5)
    pipe2_w = np.random.normal(50,std, amount)
    pipe2_w = pipe2_w.round(5)
    pipe2_h = np.random.normal(30,std, amount)
    pipe2_h = pipe2_h.round(5)
    
    op30_electricity = np.random.uniform(89, 100, amount)
    op30_electricity = op30_electricity.round(5)
    
    op30_l = op20_l
    op30_w = op20_w
    
    for item_30 in range(amount):
        
        if op30_electricity[item_30] < 90:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - op30_electricity[item_30] * 0.11
        else:
            op30_w[item_30] = op20_w[item_30] + pipe2_w[item_30] - 10
            
    op30_h = op20_h
    
    op30_test = []
    
    for test in range(amount):
    
        if (op30_l[test] < 199.99) or (op30_l[test] > 200.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op30_w[test] < 179.99) or (op30_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op30_h[test] < 59.99) or (op30_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op30_test.append(0)
        else:
            op30_test.append(1)
    
    ############################################################################
    
    flange1_l = np.random.normal(30,std, amount)
    flange1_l = flange1_l.round(5)
    flange1_w = np.random.normal(80,std, amount)
    flange1_w = flange1_w.round(5)
    flange1_h = np.random.normal(40,std, amount)
    flange1_h = flange1_h.round(5)
    
    op40_temperature = np.random.uniform(489, 511, amount)
    op40_temperature = op40_temperature.round(5)
    
    op40_l = op30_l
    
    for item_40 in range(amount):
        
        if 489 < op40_temperature[item_40] < 511:
            op40_l[item_40] = op30_l[item_40] + flange1_l[item_40]
        else:
            op40_l[item_40] = 0
            
    op40_w = op30_w
    op40_h = op30_h
    
    op40_test = []
    
    for test in range(amount):
    
        if (op40_l[test] < 229.99) or (op40_l[test] > 230.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op40_w[test] < 179.99) or (op40_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op40_h[test] < 59.99) or (op40_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op40_test.append(0)
        else:
            op40_test.append(1)
    
    ############################################################################
    
    flange2_l = np.random.normal(30,std, amount)
    flange2_l = flange2_l.round(5)
    flange2_w = np.random.normal(80,std, amount)
    flange2_w = flange2_w.round(5)
    flange2_h = np.random.normal(40,std, amount)
    flange2_h = flange2_h.round(5)
    
    op50_temperature = np.random.uniform(489, 511, amount)
    op50_temperature = op50_temperature.round(5)
    
    op50_l = op40_l
    
    for item_50 in range(amount):
        
        if 489 < op50_temperature[item_50] < 511:
            op50_l[item_50] = op40_l[item_50] + flange2_l[item_50]
        else:
            op50_l[item_50] = 0
            
    op50_w = op40_w
    op50_h = op40_h
    
    ############################################################################
    
    op60_test = []
    
    for test in range(amount):
    
        if (op50_l[test] < 259.99) or (op50_l[test] > 260.01):
            length_test = 1
        else:
            length_test = 0
            
        if (op50_w[test] < 179.99) or (op50_w[test] > 180.01):
            width_test = 1
        else: 
            width_test = 0
            
        if (op50_h[test] < 59.99) or (op50_h[test] > 60.01):
            height_test = 1
        else:
            height_test = 0
        
        if length_test == 0 & width_test == 0 & height_test == 0:
            op60_test.append(0)
        else:
            op60_test.append(1)
            
        
    
    ############################################################################
    
    for i in range(amount):
        item = {}
        item['item_key'] = i
        item['body_l'] = body_l[i]
        item['body_w'] = body_w[i]
        item['body_h'] = body_h[i]
        
        item['wavyfin_l'] = wavyfin_l[i]
        item['wavyfin_w'] = wavyfin_w[i]
        item['wavyfin_h'] = wavyfin_h[i]
        
        item['op10_l'] = body_l[i]
        item['op10_w'] = body_w[i]
        item['op10_h'] = wavyfin_h[i]
        item['op10_electricity'] = op10_electricity[i]
        item['op10_process_time'] = op10_process_time[i]
        item['op10_test'] = op10_test[i]

        item['pipe1_l'] = pipe1_l[i]
        item['pipe1_w'] = pipe1_w[i]
        item['pipe1_h'] = pipe1_h[i]
        
        item['op20_l'] = op20_l[i]            
        item['op20_w'] = op20_w[i]
        item['op20_h'] = op20_h[i]
        item['op20_electricity'] = op20_electricity[i]
        item['op20_process_time'] = op20_process_time[i]
        item['op20_test'] = op20_test[i]
        
        item['pipe2_l'] = pipe2_l[i]
        item['pipe2_w'] = pipe2_w[i]
        item['pipe2_h'] = pipe2_h[i]
        
        item['op30_l'] = op30_l[i]            
        item['op30_w'] = op30_w[i]
        item['op30_h'] = op30_h[i]
        item['op30_electricity'] = op30_electricity[i]
        item['op30_process_time'] = op30_process_time[i]
        item['op30_test'] = op30_test[i]
        
        item['flange1_l'] = flange1_l[i]
        item['flange1_w'] = flange1_w[i]
        item['flange1_h'] = flange1_h[i]
        
        item['op40_l'] = op40_l[i]            
        item['op40_w'] = op40_w[i]
        item['op40_h'] = op40_h[i]
        item['op40_temperature'] = op40_temperature[i]
        item['op40_process_time'] = op40_process_time[i]
        item['op40_test'] = op40_test[i]
        
        item['flange2_l'] = flange2_l[i]
        item['flange2_w'] = flange2_w[i]
        item['flange2_h'] = flange2_h[i]
        
        item['op50_l'] = op50_l[i]            
        item['op50_w'] = op50_w[i]
        item['op50_h'] = op50_h[i]
        item['op50_temperature'] = op50_temperature[i]
        item['op50_process_time'] = op50_process_time[i]
        
        item['op60_test'] = op60_test[i]
        
        item_data.append(item)
    
    return item_data

# %%
process()
# Out:
# [{'item_key': 0,
#   'body_l': 260.00493,
#   'body_w': 179.99931999999998,
#   'body_h': 50.00079,
#   'wavyfin_l': 100.00052,
#   'wavyfin_w': 49.99918,
#   'wavyfin_h': 60.00221,
#   'op10_l': 260.00493,
#   'op10_w': 179.99931999999998,
#   'op10_h': 60.00221,
#   'op10_electricity': 99.84586,
#   'op10_process_time': 6.43954,
#   'op10_test': 0,
#   'pipe1_l': 29.99877,
#   'pipe1_w': 49.99942,
#   'pipe1_h': 30.00158,
#   'op20_l': 260.00493,
#   'op20_w': 179.99931999999998,
#   'op20_h': 60.00221,
#   'op20_electricity': 98.31825,
#   'op20_process_time': 8.26662,
#   'op20_test': 0,
#   'pipe2_l': 30.002,
#   'pipe2_w': 50.00008,
#   'pipe2_h': 29.99897,
#   'op30_l': 260.00493,
#   'op30_w': 179.99931999999998,
#   'op30_h': 60.00221,
#   'op30_electricity': 96.57105,
#   'op30_process_time': 9.46782,
#   'op30_test': 0,
#   'flange1_l': 30.00067,
#   'flange1_w': 79.99816,
#   'flange1_h': 40.0008,
#   'op40_l': 260.00493,
#   'op40_w': 179.99931999999998,
#   'op40_h': 60.00221,
#   'op40_temperature': 509.50378,
#   'op40_process_time': 13.45152,
#   'op40_test': 0,
#   'flange2_l': 30.00158,
#   'flange2_w': 79.99834,
#   'flange2_h': 39.99693,
#   'op50_l': 260.00493,
#   'op50_w': 179.99931999999998,
#   'op50_h': 60.00221,
#   'op50_temperature': 505.36062,
#   'op50_process_time': 42.17444,
#   'op60_test': 0},
#  {'item_key': 1,
#   'body_l': 260.00391,
#   'body_w': 179.99975,
#   'body_h': 50.00441,
#   'wavyfin_l': 100.00061,
#   'wavyfin_w': 50.00018,
#   'wavyfin_h': 59.99945,
#   'op10_l': 260.00391,
#   'op10_w': 179.99975,
#   'op10_h': 59.99945,
#   'op10_electricity': 98.17438,
#   'op10_process_time': 5.2978,
#   'op10_test': 0,
#   'pipe1_l': 30.00141,
#   'pipe1_w': 50.00036,
#   'pipe1_h': 29.99392,
#   'op20_l': 260.00391,
#   'op20_w': 179.99975,
#   'op20_h': 59.99945,
#   'op20_electricity': 94.71213,
#   'op20_process_time': 5.66867,
#   'op20_test': 0,
#   'pipe2_l': 30.00023,
#   'pipe2_w': 49.99731,
#   'pipe2_h': 30.00016,
#   'op30_l': 260.00391,
#   'op30_w': 179.99975,
#   'op30_h': 59.99945,
#   'op30_electricity': 92.37647,
#   'op30_process_time': 22.37441,
#   'op30_test': 0,
#   'flange1_l': 29.99968,
#   'flange1_w': 79.99639,
#   'flange1_h': 39.9985,
#   'op40_l': 260.00391,
#   'op40_w': 179.99975,
#   'op40_h': 59.99945,
#   'op40_temperature': 510.92646,
#   'op40_process_time': 7.13304,
#   'op40_test': 0,
#   'flange2_l': 30.00269,
#   'flange2_w': 79.99935,
#   'flange2_h': 40.00008,
#   'op50_l': 260.00391,
#   'op50_w': 179.99975,
#   'op50_h': 59.99945,
#   'op50_temperature': 505.99244,
#   'op50_process_time': 4.13323,
#   'op60_test': 0},
#  {'item_key': 2,
#   'body_l': 259.99642,
#   'body_w': 179.99263,
#   'body_h': 50.00033,
#   'wavyfin_l': 99.99518,
#   'wavyfin_w': 49.99876,
#   'wavyfin_h': 59.99947,
#   'op10_l': 259.99642,
#   'op10_w': 179.99263,
#   'op10_h': 59.99947,
#   'op10_electricity': 92.52469,
#   'op10_process_time': 20.18346,
#   'op10_test': 0,
#   'pipe1_l': 29.99888,
#   'pipe1_w': 49.99861,
#   'pipe1_h': 29.99859,
#   'op20_l': 259.99642,
#   'op20_w': 179.99263,
#   'op20_h': 59.99947,
#   'op20_electricity': 92.10071,
#   'op20_process_time': 0.91543,
#   'op20_test': 0,
#   'pipe2_l': 29.99943,
#   'pipe2_w': 49.99558,
#   'pipe2_h': 29.99971,
#   'op30_l': 259.99642,
#   'op30_w': 179.99263,
#   'op30_h': 59.99947,
#   'op30_electricity': 98.61827,
#   'op30_process_time': 11.5071,
#   'op30_test': 0,
#   'flange1_l': 30.00098,
#   'flange1_w': 79.99635,
#   'flange1_h': 40.00044,
#   'op40_l': 259.99642,
#   'op40_w': 179.99263,
#   'op40_h': 59.99947,
#   'op40_temperature': 491.0401,
#   'op40_process_time': 29.04219,
#   'op40_test': 0,
#   'flange2_l': 29.99938,
#   'flange2_w': 80.00348,
#   'flange2_h': 39.99632,
#   'op50_l': 259.99642,
#   'op50_w': 179.99263,
#   'op50_h': 59.99947,
#   'op50_temperature': 491.62517,
#   'op50_process_time': 9.82071,
#   'op60_test': 0},
#  {'item_key': 3,
#   'body_l': 260.0066,
#   'body_w': 180.00304,
#   'body_h': 49.99843,
#   'wavyfin_l': 100.00016,
#   'wavyfin_w': 50.00158,
#   'wavyfin_h': 60.00015,
#   'op10_l': 260.0066,
#   'op10_w': 180.00304,
#   'op10_h': 60.00015,
#   'op10_electricity': 93.18558,
#   'op10_process_time': 2.82092,
#   'op10_test': 0,
#   'pipe1_l': 30.00152,
#   'pipe1_w': 49.9992,
#   'pipe1_h': 30.00029,
#   'op20_l': 260.0066,
#   'op20_w': 180.00304,
#   'op20_h': 60.00015,
#   'op20_electricity': 98.33612,
#   'op20_process_time': 24.28535,
#   'op20_test': 0,
#   'pipe2_l': 30.00079,
#   'pipe2_w': 50.00155,
#   'pipe2_h': 29.99908,
#   'op30_l': 260.0066,
#   'op30_w': 180.00304,
#   'op30_h': 60.00015,
#   'op30_electricity': 98.40546,
#   'op30_process_time': 4.6409,
#   'op30_test': 0,
#   'flange1_l': 30.00275,
#   'flange1_w': 79.99436,
#   'flange1_h': 39.99979,
#   'op40_l': 260.0066,
#   'op40_w': 180.00304,
#   'op40_h': 60.00015,
#   'op40_temperature': 489.0169,
#   'op40_process_time': 0.63805,
#   'op40_test': 0,
#   'flange2_l': 29.99911,
#   'flange2_w': 79.99879,
#   'flange2_h': 39.99983,
#   'op50_l': 260.0066,
#   'op50_w': 180.00304,
#   'op50_h': 60.00015,
#   'op50_temperature': 496.56522,
#   'op50_process_time': 1.63956,
#   'op60_test': 0},
#  {'item_key': 4,
#   'body_l': 260.00030000000004,
#   'body_w': 180.1573872,
#   'body_h': 50.0011,
#   'wavyfin_l': 99.9997,
#   'wavyfin_w': 49.99977,
#   'wavyfin_h': 59.99608,
#   'op10_l': 260.00030000000004,
#   'op10_w': 180.1573872,
#   'op10_h': 59.99608,
#   'op10_electricity': 93.41384,
#   'op10_process_time': 0.90739,
#   'op10_test': 0,
#   'pipe1_l': 30.00168,
#   'pipe1_w': 49.99252,
#   'pipe1_h': 30.00186,
#   'op20_l': 260.00030000000004,
#   'op20_w': 180.1573872,
#   'op20_h': 59.99608,
#   'op20_electricity': 89.43248,
#   'op20_process_time': 0.3873,
#   'op20_test': 0,
#   'pipe2_l': 29.99844,
#   'pipe2_w': 50.0007,
#   'pipe2_h': 29.99772,
#   'op30_l': 260.00030000000004,
#   'op30_w': 180.1573872,
#   'op30_h': 59.99608,
#   'op30_electricity': 95.47996,
#   'op30_process_time': 17.96338,
#   'op30_test': 0,
#   'flange1_l': 30.00004,
#   'flange1_w': 80.0,
#   'flange1_h': 39.99639,
#   'op40_l': 260.00030000000004,
#   'op40_w': 180.1573872,
#   'op40_h': 59.99608,
#   'op40_temperature': 497.76959,
#   'op40_process_time': 10.49865,
#   'op40_test': 0,
#   'flange2_l': 29.99936,
#   'flange2_w': 79.99486,
#   'flange2_h': 39.99879,
#   'op50_l': 260.00030000000004,
#   'op50_w': 180.1573872,
#   'op50_h': 59.99608,
#   'op50_temperature': 510.0717,
#   'op50_process_time': 10.33591,
#   'op60_test': 0},
#  {'item_key': 5,
#   'body_l': 260.00034,
#   'body_w': 179.99657000000002,
#   'body_h': 49.99967,
#   'wavyfin_l': 100.00661,
#   'wavyfin_w': 49.99917,
#   'wavyfin_h': 60.00078,
#   'op10_l': 260.00034,
#   'op10_w': 179.99657000000002,
#   'op10_h': 60.00078,
#   'op10_electricity': 89.20099,
#   'op10_process_time': 9.76866,
#   'op10_test': 0,
#   'pipe1_l': 29.99977,
#   'pipe1_w': 49.99718,
#   'pipe1_h': 29.99871,
#   'op20_l': 260.00034,
#   'op20_w': 179.99657000000002,
#   'op20_h': 60.00078,
#   'op20_electricity': 92.74553,
#   'op20_process_time': 0.80708,
#   'op20_test': 0,
#   'pipe2_l': 30.00028,
#   'pipe2_w': 50.00182,
#   'pipe2_h': 29.99875,
#   'op30_l': 260.00034,
#   'op30_w': 179.99657000000002,
#   'op30_h': 60.00078,
#   'op30_electricity': 92.26099,
#   'op30_process_time': 38.85703,
#   'op30_test': 0,
#   'flange1_l': 30.00165,
#   'flange1_w': 80.00159,
#   'flange1_h': 40.00305,
#   'op40_l': 260.00034,
#   'op40_w': 179.99657000000002,
#   'op40_h': 60.00078,
#   'op40_temperature': 491.69932,
#   'op40_process_time': 4.82512,
#   'op40_test': 0,
#   'flange2_l': 30.00101,
#   'flange2_w': 79.99937,
#   'flange2_h': 40.00184,
#   'op50_l': 260.00034,
#   'op50_w': 179.99657000000002,
#   'op50_h': 60.00078,
#   'op50_temperature': 498.31058,
#   'op50_process_time': 10.27549,
#   'op60_test': 0},
#  {'item_key': 6,
#   'body_l': 259.99643000000003,
#   'body_w': 180.1096309,
#   'body_h': 49.99846,
#   'wavyfin_l': 99.99952,
#   'wavyfin_w': 49.99743,
#   'wavyfin_h': 60.00285,
#   'op10_l': 259.99643000000003,
#   'op10_w': 180.1096309,
#   'op10_h': 60.00285,
#   'op10_electricity': 90.32702,
#   'op10_process_time': 12.04815,
#   'op10_test': 0,
#   'pipe1_l': 29.99777,
#   'pipe1_w': 50.00065,
#   'pipe1_h': 30.00219,
#   'op20_l': 259.99643000000003,
#   'op20_w': 180.1096309,
#   'op20_h': 60.00285,
#   'op20_electricity': 89.92281,
#   'op20_process_time': 3.45138,
#   'op20_test': 0,
#   'pipe2_l': 30.00495,
#   'pipe2_w': 49.99851,
#   'pipe2_h': 29.99645,
#   'op30_l': 259.99643000000003,
#   'op30_w': 180.1096309,
#   'op30_h': 60.00285,
#   'op30_electricity': 99.83678,
#   'op30_process_time': 0.85918,
#   'op30_test': 0,
#   'flange1_l': 29.99789,
#   'flange1_w': 79.99787,
#   'flange1_h': 39.99707,
#   'op40_l': 259.99643000000003,
#   'op40_w': 180.1096309,
#   'op40_h': 60.00285,
#   'op40_temperature': 496.19508,
#   'op40_process_time': 1.25135,
#   'op40_test': 0,
#   'flange2_l': 30.00157,
#   'flange2_w': 79.99712,
#   'flange2_h': 39.99844,
#   'op50_l': 259.99643000000003,
#   'op50_w': 180.1096309,
#   'op50_h': 60.00285,
#   'op50_temperature': 494.41756,
#   'op50_process_time': 1.77236,
#   'op60_test': 0},
#  {'item_key': 7,
#   'body_l': 260.00439,
#   'body_w': 180.00144999999998,
#   'body_h': 50.00056,
#   'wavyfin_l': 100.00139,
#   'wavyfin_w': 49.99926,
#   'wavyfin_h': 59.99885,
#   'op10_l': 260.00439,
#   'op10_w': 180.00144999999998,
#   'op10_h': 59.99885,
#   'op10_electricity': 96.30612,
#   'op10_process_time': 4.29263,
#   'op10_test': 0,
#   'pipe1_l': 30.00245,
#   'pipe1_w': 50.00471,
#   'pipe1_h': 30.0025,
#   'op20_l': 260.00439,
#   'op20_w': 180.00144999999998,
#   'op20_h': 59.99885,
#   'op20_electricity': 90.82856,
#   'op20_process_time': 11.71794,
#   'op20_test': 0,
#   'pipe2_l': 29.99704,
#   'pipe2_w': 49.99879,
#   'pipe2_h': 30.00115,
#   'op30_l': 260.00439,
#   'op30_w': 180.00144999999998,
#   'op30_h': 59.99885,
#   'op30_electricity': 90.47246,
#   'op30_process_time': 13.26115,
#   'op30_test': 0,
#   'flange1_l': 30.00289,
#   'flange1_w': 79.99842,
#   'flange1_h': 39.9974,
#   'op40_l': 260.00439,
#   'op40_w': 180.00144999999998,
#   'op40_h': 59.99885,
#   'op40_temperature': 491.14888,
#   'op40_process_time': 5.48102,
#   'op40_test': 0,
#   'flange2_l': 30.00061,
#   'flange2_w': 79.99859,
#   'flange2_h': 40.00193,
#   'op50_l': 260.00439,
#   'op50_w': 180.00144999999998,
#   'op50_h': 59.99885,
#   'op50_temperature': 497.21509,
#   'op50_process_time': 15.38159,
#   'op60_test': 0},
#  {'item_key': 8,
#   'body_l': 260.00717,
#   'body_w': 180.00231,
#   'body_h': 50.00389,
#   'wavyfin_l': 99.99946,
#   'wavyfin_w': 49.99832,
#   'wavyfin_h': 60.00033,
#   'op10_l': 260.00717,
#   'op10_w': 180.00231,
#   'op10_h': 60.00033,
#   'op10_electricity': 97.31985,
#   'op10_process_time': 7.68018,
#   'op10_test': 0,
#   'pipe1_l': 29.99916,
#   'pipe1_w': 50.00273,
#   'pipe1_h': 30.00172,
#   'op20_l': 260.00717,
#   'op20_w': 180.00231,
#   'op20_h': 60.00033,
#   'op20_electricity': 90.80238,
#   'op20_process_time': 5.26366,
#   'op20_test': 0,
#   'pipe2_l': 30.00268,
#   'pipe2_w': 49.99994,
#   'pipe2_h': 29.9974,
#   'op30_l': 260.00717,
#   'op30_w': 180.00231,
#   'op30_h': 60.00033,
#   'op30_electricity': 90.34189,
#   'op30_process_time': 12.44535,
#   'op30_test': 0,
#   'flange1_l': 30.00132,
#   'flange1_w': 80.00141,
#   'flange1_h': 40.00075,
#   'op40_l': 260.00717,
#   'op40_w': 180.00231,
#   'op40_h': 60.00033,
#   'op40_temperature': 496.79746,
#   'op40_process_time': 13.65959,
#   'op40_test': 0,
#   'flange2_l': 30.0047,
#   'flange2_w': 80.00113,
#   'flange2_h': 39.99606,
#   'op50_l': 260.00717,
#   'op50_w': 180.00231,
#   'op50_h': 60.00033,
#   'op50_temperature': 505.14858,
#   'op50_process_time': 2.97723,
#   'op60_test': 0},
#  {'item_key': 9,
#   'body_l': 259.99693,
#   'body_w': 179.9981,
#   'body_h': 49.99686,
#   'wavyfin_l': 100.00221,
#   'wavyfin_w': 49.99933,
#   'wavyfin_h': 59.99431,
#   'op10_l': 259.99693,
#   'op10_w': 179.9981,
#   'op10_h': 59.99431,
#   'op10_electricity': 94.19132,
#   'op10_process_time': 12.00499,
#   'op10_test': 0,
#   'pipe1_l': 30.00221,
#   'pipe1_w': 49.99662,
#   'pipe1_h': 30.00341,
#   'op20_l': 259.99693,
#   'op20_w': 179.9981,
#   'op20_h': 59.99431,
#   'op20_electricity': 90.52343,
#   'op20_process_time': 1.54092,
#   'op20_test': 0,
#   'pipe2_l': 30.00135,
#   'pipe2_w': 49.99997,
#   'pipe2_h': 29.99543,
#   'op30_l': 259.99693,
#   'op30_w': 179.9981,
#   'op30_h': 59.99431,
#   'op30_electricity': 98.38026,
#   'op30_process_time': 12.40852,
#   'op30_test': 0,
#   'flange1_l': 30.00076,
#   'flange1_w': 79.99797,
#   'flange1_h': 39.99851,
#   'op40_l': 259.99693,
#   'op40_w': 179.9981,
#   'op40_h': 59.99431,
#   'op40_temperature': 504.94664,
#   'op40_process_time': 4.54585,
#   'op40_test': 0,
#   'flange2_l': 29.9943,
#   'flange2_w': 79.99962,
#   'flange2_h': 40.0021,
#   'op50_l': 259.99693,
#   'op50_w': 179.9981,
#   'op50_h': 59.99431,
#   'op50_temperature': 508.00584,
#   'op50_process_time': 9.15205,
#   'op60_test': 0}]

# %%
result_df = pd.DataFrame(process())
result_df = result_df.set_index('item_key')

# %%
result_df.to_excel("item_data.xlsx")

# %%
data_load = pd.read_excel("item_data.xlsx")

num_list = len(data_load)

print(num_list)
data_load
# Out:
# 10
#    item_key    body_h     body_l     body_w  flange1_h  flange1_l  flange1_w  \
# 0         0  50.00447  260.00254  179.99723   40.00160   29.99886   80.00194
# 1         1  49.99498  259.99694  179.99754   40.00027   29.99698   79.99837
# 2         2  49.99978  259.99273  180.00315   40.00051   29.99787   79.99966
# 3         3  49.99965  259.99696  179.99871   39.99776   29.99595   79.99585
# 4         4  50.00006  260.00263  179.99426   40.00077   30.00302   79.99977
# 5         5  50.00259  259.99965  180.00634   40.00181   29.99742   80.00113
# 6         6  49.99993  260.00066  180.00777   40.00007   30.00071   79.99772
# 7         7  50.00265  260.00408  180.00557   40.00100   30.00131   79.99975
# 8         8  49.99917  260.00191  179.99396   40.00039   30.00294   80.00193
# 9         9  50.00125  260.00691  179.99648   39.99951   30.00189   79.99598
#
#    flange2_h  flange2_l  flange2_w  ...  op60_test   pipe1_h   pipe1_l  \
# 0   40.00105   30.00263   79.99480  ...          0  29.99797  30.00012
# 1   39.99853   30.00038   80.00326  ...          0  30.00293  30.00195
# 2   40.00143   29.99783   79.99978  ...          0  29.99837  29.99705
# 3   39.99812   30.00059   80.00156  ...          0  29.99990  30.00221
# 4   39.99996   29.99888   80.00293  ...          0  30.00302  30.00472
# 5   40.00054   29.99978   79.99962  ...          0  30.00532  29.99956
# 6   40.00009   29.99593   80.00290  ...          0  29.99551  30.00034
# 7   39.99947   30.00049   80.00143  ...          0  30.00190  30.00103
# 8   39.99887   29.99840   80.00203  ...          0  30.00539  30.00033
# 9   40.00014   30.00227   79.99572  ...          0  30.00008  30.00209
#
#     pipe1_w   pipe2_h   pipe2_l   pipe2_w  wavyfin_h  wavyfin_l  wavyfin_w
# 0  49.99902  29.99970  30.00327  49.99730   60.00484  100.00389   49.99706
# 1  49.99925  29.99843  29.99881  49.99853   60.00143  100.00181   50.00402
# 2  50.00366  29.99892  29.99598  49.99807   59.99645   99.99842   49.99973
# 3  49.99839  30.00432  29.99881  50.00121   60.00060  100.00132   50.00191
# 4  49.99764  29.99999  30.00283  49.99932   60.00233   99.99580   50.00474
# 5  50.00343  29.99969  30.00001  50.00214   59.99445  100.00431   50.00048
# 6  50.00835  29.99326  30.00163  50.00212   59.99627   99.99557   49.99717
# 7  50.00552  29.99769  29.99951  49.99822   60.00246   99.99912   49.99879
# 8  49.99828  30.00049  29.99873  49.99546   59.99619  100.00259   50.00030
# 9  50.00441  29.99739  29.99984  49.99349   59.99785  100.00058   49.99857
#
# [10 rows x 49 columns]
