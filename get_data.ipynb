# %%
import pymysql
import pandas as pd

# %% [markdown]
# ## 품질데이터 가져오기

# %%
def get_quality_data_list_for_predict():
    conn = pymysql.connect(host='127.0.0.1', user='root', password='carry789', db='projectdata', charset='utf8')

    sql = '''
        select product_key, product_size_l, product_size_w, product_size_h, product_test
        from product_quality
    '''

    cursor = conn.cursor()
    cursor.execute(sql)
    row = cursor.fetchall()

    data_list = []

    for obj in row:
        data_dic = {
            'product_key': obj[0],
            'product_size_l': obj[1],
            'product_size_w': obj[2],
            'product_size_h': obj[3],
            'product_test' : obj[4]
        }
        data_list.append(data_dic)

    conn.close()

    return data_list

# %%
quality_data = get_quality_data_list_for_predict()

# %%
quality_df = pd.DataFrame(quality_data)

# %%
quality_df.head()
# Out:
#                           product_key  product_size_h  product_size_l  \
# 0     2020-10-31 16:38:15.951609-W1P0         60.0001        200.0010
# 1     2020-10-31 16:38:15.951609-body         49.9983        200.0010
# 2  2020-10-31 16:38:15.951609-wavyfin         60.0001         99.9994
# 3     2020-10-31 16:38:25.871779-W2P0         60.0001        200.0010
# 4    2020-10-31 16:38:25.871779-pipe1         30.0007         29.9990
#
#    product_size_w product_test
# 0         99.9996           OK
# 1         99.9996           OK
# 2         49.9968           OK
# 3        139.9980           OK
# 4         49.9981           OK

# %%
quality_data
# Out:
# [{'product_key': '2020-10-31 16:38:15.951609-W1P0',
#   'product_size_l': 200.001,
#   'product_size_w': 99.9996,
#   'product_size_h': 60.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:15.951609-body',
#   'product_size_l': 200.001,
#   'product_size_w': 99.9996,
#   'product_size_h': 49.9983,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:15.951609-wavyfin',
#   'product_size_l': 99.9994,
#   'product_size_w': 49.9968,
#   'product_size_h': 60.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:25.871779-W2P0',
#   'product_size_l': 200.001,
#   'product_size_w': 139.998,
#   'product_size_h': 60.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:25.871779-pipe1',
#   'product_size_l': 29.999,
#   'product_size_w': 49.9981,
#   'product_size_h': 30.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:35.729839-W3P0',
#   'product_size_l': 200.001,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:35.729839-pipe2',
#   'product_size_l': 29.9949,
#   'product_size_w': 50.0008,
#   'product_size_h': 30.0014,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:45.587019-W4P0',
#   'product_size_l': 229.996,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:45.587019-flange1',
#   'product_size_l': 29.9945,
#   'product_size_w': 80.005,
#   'product_size_h': 39.9989,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:54.696989-W5P0',
#   'product_size_l': 259.997,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:54.696989-flange2',
#   'product_size_l': 30.0018,
#   'product_size_w': 80.0032,
#   'product_size_h': 39.9973,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:04.376949-W6P0',
#   'product_size_l': 259.997,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:25.877709-W1P1',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9967,
#   'product_size_h': 60.0057,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:25.877709-body',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9967,
#   'product_size_h': 50.0004,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:25.877709-wavyfin',
#   'product_size_l': 99.9994,
#   'product_size_w': 50.0027,
#   'product_size_h': 60.0057,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:35.654489-W2P1',
#   'product_size_l': 199.999,
#   'product_size_w': 139.997,
#   'product_size_h': 60.0057,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:35.654489-pipe1',
#   'product_size_l': 30.0047,
#   'product_size_w': 50.0005,
#   'product_size_h': 29.9994,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:45.507849-W3P1',
#   'product_size_l': 199.999,
#   'product_size_w': 179.995,
#   'product_size_h': 60.0057,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:45.507849-pipe2',
#   'product_size_l': 29.9978,
#   'product_size_w': 49.9976,
#   'product_size_h': 30.003,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:55.381499-W4P1',
#   'product_size_l': 229.999,
#   'product_size_w': 179.995,
#   'product_size_h': 60.0057,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:55.381499-flange1',
#   'product_size_l': 29.9996,
#   'product_size_w': 79.9997,
#   'product_size_h': 40.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:04.912859-W5P1',
#   'product_size_l': 259.997,
#   'product_size_w': 179.995,
#   'product_size_h': 60.0057,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:04.912859-flange2',
#   'product_size_l': 29.9978,
#   'product_size_w': 79.9976,
#   'product_size_h': 39.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:14.642119-W6P1',
#   'product_size_l': 259.997,
#   'product_size_w': 179.995,
#   'product_size_h': 60.0057,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:35.689589-W1P2',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9991,
#   'product_size_h': 60.0035,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:35.689589-body',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9991,
#   'product_size_h': 50.0002,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:35.689589-wavyfin',
#   'product_size_l': 100.004,
#   'product_size_w': 50.0012,
#   'product_size_h': 60.0035,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:45.573209-W2P2',
#   'product_size_l': 199.999,
#   'product_size_w': 139.996,
#   'product_size_h': 60.0035,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:45.573209-pipe1',
#   'product_size_l': 30.0033,
#   'product_size_w': 49.9968,
#   'product_size_h': 29.9987,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:55.378109-W3P2',
#   'product_size_l': 199.999,
#   'product_size_w': 179.994,
#   'product_size_h': 60.0035,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:55.378109-pipe2',
#   'product_size_l': 29.9971,
#   'product_size_w': 49.9978,
#   'product_size_h': 30.002,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:04.847949-W4P2',
#   'product_size_l': 229.995,
#   'product_size_w': 179.994,
#   'product_size_h': 60.0035,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:04.847949-flange1',
#   'product_size_l': 29.9961,
#   'product_size_w': 80.0058,
#   'product_size_h': 40.0014,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:14.828379-W5P2',
#   'product_size_l': 259.996,
#   'product_size_w': 179.994,
#   'product_size_h': 60.0035,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:14.828379-flange2',
#   'product_size_l': 30.0011,
#   'product_size_w': 79.9972,
#   'product_size_h': 40.0037,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:24.709599-W6P2',
#   'product_size_l': 259.996,
#   'product_size_w': 179.994,
#   'product_size_h': 60.0035,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:44.829799-W1P3',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9965,
#   'product_size_h': 60.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:44.829799-body',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9965,
#   'product_size_h': 49.9978,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:44.829799-wavyfin',
#   'product_size_l': 99.9996,
#   'product_size_w': 50.0007,
#   'product_size_h': 60.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:55.561289-W2P3',
#   'product_size_l': 199.999,
#   'product_size_w': 139.996,
#   'product_size_h': 60.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:55.561289-pipe1',
#   'product_size_l': 30.0026,
#   'product_size_w': 49.9999,
#   'product_size_h': 30.0024,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:05.340899-W3P3',
#   'product_size_l': 199.999,
#   'product_size_w': 179.997,
#   'product_size_h': 60.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:05.340899-pipe2',
#   'product_size_l': 29.9989,
#   'product_size_w': 50.001,
#   'product_size_h': 29.9991,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:14.659359-W4P3',
#   'product_size_l': 229.996,
#   'product_size_w': 179.997,
#   'product_size_h': 60.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:14.659359-flange1',
#   'product_size_l': 29.9973,
#   'product_size_w': 79.9949,
#   'product_size_h': 40.0008,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:23.956099-W5P3',
#   'product_size_l': 259.996,
#   'product_size_w': 179.997,
#   'product_size_h': 60.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:23.956099-flange2',
#   'product_size_l': 30.0002,
#   'product_size_w': 79.9991,
#   'product_size_h': 39.9979,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:33.261319-W6P3',
#   'product_size_l': 259.996,
#   'product_size_w': 179.997,
#   'product_size_h': 60.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:54.165049-W1P4',
#   'product_size_l': 199.999,
#   'product_size_w': 100.005,
#   'product_size_h': 60.0012,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:54.165049-body',
#   'product_size_l': 199.999,
#   'product_size_w': 100.005,
#   'product_size_h': 50.0025,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:38:54.165049-wavyfin',
#   'product_size_l': 99.9983,
#   'product_size_w': 50.0028,
#   'product_size_h': 60.0012,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:05.212459-W2P4',
#   'product_size_l': 199.999,
#   'product_size_w': 140.009,
#   'product_size_h': 60.0012,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:05.212459-pipe1',
#   'product_size_l': 29.9999,
#   'product_size_w': 50.0046,
#   'product_size_h': 30.0037,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:15.333279-W3P4',
#   'product_size_l': 199.999,
#   'product_size_w': 180.008,
#   'product_size_h': 60.0012,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:15.333279-pipe2',
#   'product_size_l': 30.0022,
#   'product_size_w': 49.9988,
#   'product_size_h': 30.0051,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:24.828239-W4P4',
#   'product_size_l': 229.999,
#   'product_size_w': 180.008,
#   'product_size_h': 60.0012,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:24.828239-flange1',
#   'product_size_l': 29.9993,
#   'product_size_w': 80.0016,
#   'product_size_h': 39.9985,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.798559-W5P4',
#   'product_size_l': 260.003,
#   'product_size_w': 180.008,
#   'product_size_h': 60.0012,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.798559-flange2',
#   'product_size_l': 30.004,
#   'product_size_w': 80.0012,
#   'product_size_h': 39.9984,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:44.534059-W6P4',
#   'product_size_l': 260.003,
#   'product_size_w': 180.008,
#   'product_size_h': 60.0012,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:03.774379-W1P5',
#   'product_size_l': 200.0,
#   'product_size_w': 100.001,
#   'product_size_h': 59.9995,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:03.774379-body',
#   'product_size_l': 200.0,
#   'product_size_w': 100.001,
#   'product_size_h': 50.0013,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:03.774379-wavyfin',
#   'product_size_l': 99.9968,
#   'product_size_w': 50.001,
#   'product_size_h': 59.9995,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:15.066059-W2P5',
#   'product_size_l': 200.0,
#   'product_size_w': 140.004,
#   'product_size_h': 59.9995,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:15.066059-pipe1',
#   'product_size_l': 30.0024,
#   'product_size_w': 50.0033,
#   'product_size_h': 29.9991,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:24.717329-W3P5',
#   'product_size_l': 200.0,
#   'product_size_w': 180.002,
#   'product_size_h': 59.9995,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:24.717329-pipe2',
#   'product_size_l': 30.0019,
#   'product_size_w': 49.9979,
#   'product_size_h': 29.9998,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.692839-W4P5',
#   'product_size_l': 229.998,
#   'product_size_w': 180.002,
#   'product_size_h': 59.9995,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.692839-flange1',
#   'product_size_l': 29.9979,
#   'product_size_w': 80.0,
#   'product_size_h': 39.9999,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:44.525079-W5P5',
#   'product_size_l': 259.999,
#   'product_size_w': 180.002,
#   'product_size_h': 59.9995,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:44.525079-flange2',
#   'product_size_l': 30.0012,
#   'product_size_w': 80.0026,
#   'product_size_h': 40.0045,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:54.014949-W6P5',
#   'product_size_l': 259.999,
#   'product_size_w': 180.002,
#   'product_size_h': 59.9995,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:13.159439-W1P6',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9968,
#   'product_size_h': 60.0036,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:13.159439-body',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9968,
#   'product_size_h': 50.0019,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:13.159439-wavyfin',
#   'product_size_l': 99.9996,
#   'product_size_w': 50.0019,
#   'product_size_h': 60.0036,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:24.558609-W2P6',
#   'product_size_l': 199.999,
#   'product_size_w': 139.998,
#   'product_size_h': 60.0036,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:24.558609-pipe1',
#   'product_size_l': 29.9996,
#   'product_size_w': 50.0017,
#   'product_size_h': 29.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.503369-W3P6',
#   'product_size_l': 199.999,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0036,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.503369-pipe2',
#   'product_size_l': 30.0036,
#   'product_size_w': 49.9995,
#   'product_size_h': 30.0001,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:43.702829-W4P6',
#   'product_size_l': 229.996,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0036,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:43.702829-flange1',
#   'product_size_l': 29.9972,
#   'product_size_w': 79.9967,
#   'product_size_h': 39.998,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:53.469739-W5P6',
#   'product_size_l': 259.998,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0036,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:53.469739-flange2',
#   'product_size_l': 30.0016,
#   'product_size_w': 80.0025,
#   'product_size_h': 39.9974,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:02.884699-W6P6',
#   'product_size_l': 259.998,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0036,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:23.019919-W1P7',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9975,
#   'product_size_h': 60.0049,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:23.019919-body',
#   'product_size_l': 199.999,
#   'product_size_w': 99.9975,
#   'product_size_h': 49.9977,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:23.019919-wavyfin',
#   'product_size_l': 100.002,
#   'product_size_w': 49.9978,
#   'product_size_h': 60.0049,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.414039-W2P7',
#   'product_size_l': 199.999,
#   'product_size_w': 139.999,
#   'product_size_h': 60.0049,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:34.414039-pipe1',
#   'product_size_l': 30.0036,
#   'product_size_w': 50.0018,
#   'product_size_h': 30.0007,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:44.444259-W3P7',
#   'product_size_l': 199.999,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0049,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:44.444259-pipe2',
#   'product_size_l': 30.0028,
#   'product_size_w': 49.9987,
#   'product_size_h': 29.9954,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:54.044599-W4P7',
#   'product_size_l': 229.999,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0049,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:54.044599-flange1',
#   'product_size_l': 30.0,
#   'product_size_w': 79.9997,
#   'product_size_h': 40.0003,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:03.888589-W5P7',
#   'product_size_l': 259.997,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0049,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:03.888589-flange2',
#   'product_size_l': 29.9974,
#   'product_size_w': 79.9981,
#   'product_size_h': 40.0002,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:13.331249-W6P7',
#   'product_size_l': 259.997,
#   'product_size_w': 179.998,
#   'product_size_h': 60.0049,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:32.432829-W1P8',
#   'product_size_l': 199.996,
#   'product_size_w': 99.9987,
#   'product_size_h': 59.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:32.432829-body',
#   'product_size_l': 199.996,
#   'product_size_w': 99.9987,
#   'product_size_h': 49.998,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:32.432829-wavyfin',
#   'product_size_l': 100.002,
#   'product_size_w': 49.9977,
#   'product_size_h': 59.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:44.113219-W2P8',
#   'product_size_l': 199.996,
#   'product_size_w': 140.001,
#   'product_size_h': 59.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:44.113219-pipe1',
#   'product_size_l': 29.9948,
#   'product_size_w': 50.0027,
#   'product_size_h': 29.9966,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:54.374529-W3P8',
#   'product_size_l': 199.996,
#   'product_size_w': 179.999,
#   'product_size_h': 59.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:54.374529-pipe2',
#   'product_size_l': 29.9965,
#   'product_size_w': 49.9981,
#   'product_size_h': 30.0008,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:03.669299-W4P8',
#   'product_size_l': 229.997,
#   'product_size_w': 179.999,
#   'product_size_h': 59.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:03.669299-flange1',
#   'product_size_l': 30.0005,
#   'product_size_w': 80.0,
#   'product_size_h': 39.9987,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:13.183039-W5P8',
#   'product_size_l': 259.995,
#   'product_size_w': 179.999,
#   'product_size_h': 59.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:13.183039-flange2',
#   'product_size_l': 29.9986,
#   'product_size_w': 80.0021,
#   'product_size_h': 40.004,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:22.232409-W6P8',
#   'product_size_l': 259.995,
#   'product_size_w': 179.999,
#   'product_size_h': 59.9996,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:42.125449-W1P9',
#   'product_size_l': 200.003,
#   'product_size_w': 100.003,
#   'product_size_h': 59.9978,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:42.125449-body',
#   'product_size_l': 200.003,
#   'product_size_w': 100.003,
#   'product_size_h': 49.9963,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:42.125449-wavyfin',
#   'product_size_l': 99.9982,
#   'product_size_w': 49.9984,
#   'product_size_h': 59.9978,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:53.910359-W2P9',
#   'product_size_l': 200.003,
#   'product_size_w': 140.004,
#   'product_size_h': 59.9978,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:39:53.910359-pipe1',
#   'product_size_l': 30.0014,
#   'product_size_w': 50.0008,
#   'product_size_h': 30.0004,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:03.979229-W3P9',
#   'product_size_l': 200.003,
#   'product_size_w': 180.151,
#   'product_size_h': 59.9978,
#   'product_test': 'NOK'},
#  {'product_key': '2020-10-31 16:40:03.979229-pipe2',
#   'product_size_l': 30.0028,
#   'product_size_w': 49.9997,
#   'product_size_h': 29.9997,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:13.768829-W4P9',
#   'product_size_l': 230.002,
#   'product_size_w': 180.151,
#   'product_size_h': 59.9978,
#   'product_test': 'NOK'},
#  {'product_key': '2020-10-31 16:40:13.768829-flange1',
#   'product_size_l': 29.9987,
#   'product_size_w': 80.0015,
#   'product_size_h': 39.9977,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:23.061739-W5P9',
#   'product_size_l': 259.997,
#   'product_size_w': 180.151,
#   'product_size_h': 59.9978,
#   'product_test': 'NOK'},
#  {'product_key': '2020-10-31 16:40:23.061739-flange2',
#   'product_size_l': 29.9957,
#   'product_size_w': 79.9964,
#   'product_size_h': 40.0002,
#   'product_test': 'OK'},
#  {'product_key': '2020-10-31 16:40:33.021159-W6P9',
#   'product_size_l': 259.997,
#   'product_size_w': 180.151,
#   'product_size_h': 59.9978,
#   'product_test': 'NOK'}]

# %% [markdown]
# ## 설비 데이터 가져오기

# %%
def get_machine_data_list_for_predict():
    conn = pymysql.connect(host='127.0.0.1', user='root', password='carry789', db='projectdata', charset='utf8')

    sql = '''
        select product_key, machine_data, machine_data_code, process_time, end_time
        from machine
    '''

    cursor = conn.cursor()
    cursor.execute(sql)
    row = cursor.fetchall()

    data_list = []

    for obj in row:
        data_dic = {
            'product_key' : obj[0],
            'machine_data': obj[1],
            'machine_data_code': obj[2],
            'process_time': obj[3],
            'end_time': obj[4]
        }
        data_list.append(data_dic)

    conn.close()

    return data_list

# %%
machine_data = get_machine_data_list_for_predict()

# %%
machine_data
# Out:
# [{'product_key': '2020-10-31 16:38:15.951609-W1P0',
#   'machine_data': 96.3835,
#   'machine_data_code': 'E01',
#   'process_time': 9.56103,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 16)},
#  {'product_key': '2020-10-31 16:38:25.871779-W2P0',
#   'machine_data': 99.4246,
#   'machine_data_code': 'E01',
#   'process_time': 9.92017,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 26)},
#  {'product_key': '2020-10-31 16:38:35.729839-W3P0',
#   'machine_data': 92.004,
#   'machine_data_code': 'E01',
#   'process_time': 9.85806,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 36)},
#  {'product_key': '2020-10-31 16:38:45.587019-W4P0',
#   'machine_data': 506.854,
#   'machine_data_code': 'T01',
#   'process_time': 9.85718,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 46)},
#  {'product_key': '2020-10-31 16:38:54.696989-W5P0',
#   'machine_data': 508.294,
#   'machine_data_code': 'T01',
#   'process_time': 9.10997,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 55)},
#  {'product_key': '2020-10-31 16:39:04.376949-W6P0',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.67996,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 4)},
#  {'product_key': '2020-10-31 16:38:25.877709-W1P1',
#   'machine_data': 96.1544,
#   'machine_data_code': 'E01',
#   'process_time': 9.9261,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 26)},
#  {'product_key': '2020-10-31 16:38:35.654489-W2P1',
#   'machine_data': 99.306,
#   'machine_data_code': 'E01',
#   'process_time': 9.77678,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 36)},
#  {'product_key': '2020-10-31 16:38:45.507849-W3P1',
#   'machine_data': 90.5035,
#   'machine_data_code': 'E01',
#   'process_time': 9.77801,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 46)},
#  {'product_key': '2020-10-31 16:38:55.381499-W4P1',
#   'machine_data': 498.741,
#   'machine_data_code': 'T01',
#   'process_time': 9.87365,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 55)},
#  {'product_key': '2020-10-31 16:39:04.912859-W5P1',
#   'machine_data': 510.7,
#   'machine_data_code': 'T01',
#   'process_time': 9.53136,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 5)},
#  {'product_key': '2020-10-31 16:39:14.642119-W6P1',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.72926,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 15)},
#  {'product_key': '2020-10-31 16:38:35.689589-W1P2',
#   'machine_data': 89.4278,
#   'machine_data_code': 'E01',
#   'process_time': 9.81188,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 36)},
#  {'product_key': '2020-10-31 16:38:45.573209-W2P2',
#   'machine_data': 99.8145,
#   'machine_data_code': 'E01',
#   'process_time': 9.88362,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 46)},
#  {'product_key': '2020-10-31 16:38:55.378109-W3P2',
#   'machine_data': 95.8751,
#   'machine_data_code': 'E01',
#   'process_time': 9.8049,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 55)},
#  {'product_key': '2020-10-31 16:39:04.847949-W4P2',
#   'machine_data': 509.62,
#   'machine_data_code': 'T01',
#   'process_time': 9.46984,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 5)},
#  {'product_key': '2020-10-31 16:39:14.828379-W5P2',
#   'machine_data': 502.674,
#   'machine_data_code': 'T01',
#   'process_time': 9.98043,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 15)},
#  {'product_key': '2020-10-31 16:39:24.709599-W6P2',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.88122,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 25)},
#  {'product_key': '2020-10-31 16:38:44.829799-W1P3',
#   'machine_data': 91.6879,
#   'machine_data_code': 'E01',
#   'process_time': 9.14021,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 45)},
#  {'product_key': '2020-10-31 16:38:55.561289-W2P3',
#   'machine_data': 94.1436,
#   'machine_data_code': 'E01',
#   'process_time': 9.98808,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 56)},
#  {'product_key': '2020-10-31 16:39:05.340899-W3P3',
#   'machine_data': 93.8166,
#   'machine_data_code': 'E01',
#   'process_time': 9.77961,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 5)},
#  {'product_key': '2020-10-31 16:39:14.659359-W4P3',
#   'machine_data': 501.365,
#   'machine_data_code': 'T01',
#   'process_time': 9.31846,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 15)},
#  {'product_key': '2020-10-31 16:39:23.956099-W5P3',
#   'machine_data': 508.166,
#   'machine_data_code': 'T01',
#   'process_time': 9.29674,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 24)},
#  {'product_key': '2020-10-31 16:39:33.261319-W6P3',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.30522,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 33)},
#  {'product_key': '2020-10-31 16:38:54.165049-W1P4',
#   'machine_data': 90.5444,
#   'machine_data_code': 'E01',
#   'process_time': 9.33525,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 38, 54)},
#  {'product_key': '2020-10-31 16:39:05.212459-W2P4',
#   'machine_data': 96.214,
#   'machine_data_code': 'E01',
#   'process_time': 9.65117,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 5)},
#  {'product_key': '2020-10-31 16:39:15.333279-W3P4',
#   'machine_data': 98.1582,
#   'machine_data_code': 'E01',
#   'process_time': 9.99238,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 15)},
#  {'product_key': '2020-10-31 16:39:24.828239-W4P4',
#   'machine_data': 493.706,
#   'machine_data_code': 'T01',
#   'process_time': 9.49496,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 25)},
#  {'product_key': '2020-10-31 16:39:34.798559-W5P4',
#   'machine_data': 501.293,
#   'machine_data_code': 'T01',
#   'process_time': 9.97032,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 35)},
#  {'product_key': '2020-10-31 16:39:44.534059-W6P4',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.7355,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 45)},
#  {'product_key': '2020-10-31 16:39:03.774379-W1P5',
#   'machine_data': 91.6116,
#   'machine_data_code': 'E01',
#   'process_time': 9.60933,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 4)},
#  {'product_key': '2020-10-31 16:39:15.066059-W2P5',
#   'machine_data': 99.7327,
#   'machine_data_code': 'E01',
#   'process_time': 9.8536,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 15)},
#  {'product_key': '2020-10-31 16:39:24.717329-W3P5',
#   'machine_data': 90.0245,
#   'machine_data_code': 'E01',
#   'process_time': 9.38405,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 25)},
#  {'product_key': '2020-10-31 16:39:34.692839-W4P5',
#   'machine_data': 503.21,
#   'machine_data_code': 'T01',
#   'process_time': 9.97551,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 35)},
#  {'product_key': '2020-10-31 16:39:44.525079-W5P5',
#   'machine_data': 492.091,
#   'machine_data_code': 'T01',
#   'process_time': 9.83224,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 45)},
#  {'product_key': '2020-10-31 16:39:54.014949-W6P5',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.48987,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 54)},
#  {'product_key': '2020-10-31 16:39:13.159439-W1P6',
#   'machine_data': 99.5983,
#   'machine_data_code': 'E01',
#   'process_time': 9.38506,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 13)},
#  {'product_key': '2020-10-31 16:39:24.558609-W2P6',
#   'machine_data': 95.8179,
#   'machine_data_code': 'E01',
#   'process_time': 9.49255,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 25)},
#  {'product_key': '2020-10-31 16:39:34.503369-W3P6',
#   'machine_data': 98.5509,
#   'machine_data_code': 'E01',
#   'process_time': 9.78604,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 35)},
#  {'product_key': '2020-10-31 16:39:43.702829-W4P6',
#   'machine_data': 502.192,
#   'machine_data_code': 'T01',
#   'process_time': 9.19946,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 44)},
#  {'product_key': '2020-10-31 16:39:53.469739-W5P6',
#   'machine_data': 490.553,
#   'machine_data_code': 'T01',
#   'process_time': 9.76691,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 53)},
#  {'product_key': '2020-10-31 16:40:02.884699-W6P6',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.41496,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 3)},
#  {'product_key': '2020-10-31 16:39:23.019919-W1P7',
#   'machine_data': 98.4829,
#   'machine_data_code': 'E01',
#   'process_time': 9.86048,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 23)},
#  {'product_key': '2020-10-31 16:39:34.414039-W2P7',
#   'machine_data': 96.2125,
#   'machine_data_code': 'E01',
#   'process_time': 9.85543,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 34)},
#  {'product_key': '2020-10-31 16:39:44.444259-W3P7',
#   'machine_data': 93.1616,
#   'machine_data_code': 'E01',
#   'process_time': 9.94089,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 44)},
#  {'product_key': '2020-10-31 16:39:54.044599-W4P7',
#   'machine_data': 501.33,
#   'machine_data_code': 'T01',
#   'process_time': 9.60034,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 54)},
#  {'product_key': '2020-10-31 16:40:03.888589-W5P7',
#   'machine_data': 504.986,
#   'machine_data_code': 'T01',
#   'process_time': 9.84399,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 4)},
#  {'product_key': '2020-10-31 16:40:13.331249-W6P7',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.44266,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 13)},
#  {'product_key': '2020-10-31 16:39:32.432829-W1P8',
#   'machine_data': 90.2599,
#   'machine_data_code': 'E01',
#   'process_time': 9.41291,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 32)},
#  {'product_key': '2020-10-31 16:39:44.113219-W2P8',
#   'machine_data': 94.1554,
#   'machine_data_code': 'E01',
#   'process_time': 9.69918,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 44)},
#  {'product_key': '2020-10-31 16:39:54.374529-W3P8',
#   'machine_data': 92.724,
#   'machine_data_code': 'E01',
#   'process_time': 9.93027,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 54)},
#  {'product_key': '2020-10-31 16:40:03.669299-W4P8',
#   'machine_data': 506.87,
#   'machine_data_code': 'T01',
#   'process_time': 9.29477,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 4)},
#  {'product_key': '2020-10-31 16:40:13.183039-W5P8',
#   'machine_data': 507.962,
#   'machine_data_code': 'T01',
#   'process_time': 9.51374,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 13)},
#  {'product_key': '2020-10-31 16:40:22.232409-W6P8',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.04937,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 22)},
#  {'product_key': '2020-10-31 16:39:42.125449-W1P9',
#   'machine_data': 94.5471,
#   'machine_data_code': 'E01',
#   'process_time': 9.69262,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 42)},
#  {'product_key': '2020-10-31 16:39:53.910359-W2P9',
#   'machine_data': 94.3109,
#   'machine_data_code': 'E01',
#   'process_time': 9.79714,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 39, 54)},
#  {'product_key': '2020-10-31 16:40:03.979229-W3P9',
#   'machine_data': 89.5675,
#   'machine_data_code': 'E01',
#   'process_time': 9.6047,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 4)},
#  {'product_key': '2020-10-31 16:40:13.768829-W4P9',
#   'machine_data': 503.673,
#   'machine_data_code': 'T01',
#   'process_time': 9.7896,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 14)},
#  {'product_key': '2020-10-31 16:40:23.061739-W5P9',
#   'machine_data': 501.646,
#   'machine_data_code': 'T01',
#   'process_time': 9.29291,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 23)},
#  {'product_key': '2020-10-31 16:40:33.021159-W6P9',
#   'machine_data': 131.1,
#   'machine_data_code': 'TEST',
#   'process_time': 9.95942,
#   'end_time': datetime.datetime(2020, 10, 31, 16, 40, 33)}]

# %%
machine_df = pd.DataFrame(machine_data)

# %%
machine_df.head()
# Out:
#              end_time  machine_data machine_data_code  process_time  \
# 0 2020-10-31 16:38:16       96.3835               E01       9.56103
# 1 2020-10-31 16:38:26       99.4246               E01       9.92017
# 2 2020-10-31 16:38:36       92.0040               E01       9.85806
# 3 2020-10-31 16:38:46      506.8540               T01       9.85718
# 4 2020-10-31 16:38:55      508.2940               T01       9.10997
#
#                        product_key
# 0  2020-10-31 16:38:15.951609-W1P0
# 1  2020-10-31 16:38:25.871779-W2P0
# 2  2020-10-31 16:38:35.729839-W3P0
# 3  2020-10-31 16:38:45.587019-W4P0
# 4  2020-10-31 16:38:54.696989-W5P0

# %%
product_key_list = []
body_l_list = []
body_w_list = []
body_h_list = []

wavyfin_l_list = []
wavyfin_w_list = []
wavyfin_h_list = []

op10_l_list = []
op10_w_list = []
op10_h_list = []

pipe1_l_list = []
pipe1_w_list = []
pipe1_h_list = []

op20_l_list = []
op20_w_list = []
op20_h_list = []

pipe2_l_list = []
pipe2_w_list = []
pipe2_h_list = []

op30_l_list = []
op30_w_list = []
op30_h_list = []

flange1_l_list = []
flange1_w_list = []
flange1_h_list = []

op40_l_list = []
op40_w_list = []
op40_h_list = []

flange2_l_list = []
flange2_w_list = []
flange2_h_list = []

op50_l_list = []
op50_w_list = []
op50_h_list = []

op60_l_list = []
op60_w_list = []
op60_h_list = []

op10_electricity_list = []
op10_process_time_list = []

op20_electricity_list = []
op20_process_time_list = []

op30_electricity_list = []
op30_process_time_list = []

op40_temperature_list = []
op40_process_time_list = []

op50_temperature_list = []
op50_process_time_list = []

op60_process_time_list = []

op10_test_list = []
op20_test_list = []
op30_test_list = []
op40_test_list = []
op50_test_list = []
op60_test_list = []

op10_timestamp = []
op20_timestamp = []
op30_timestamp = []
op40_timestamp = []
op50_timestamp = []
op60_timestamp = []


for instance in quality_data:
    
    if (instance['product_key'][27:29] == 'W6'):
        product_key_list.append(instance['product_key'])
        
    if (instance['product_key'][27:] == 'body'):
        body_l_list.append(instance['product_size_l'])
        body_w_list.append(instance['product_size_w'])
        body_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:] == 'wavyfin'):
        wavyfin_l_list.append(instance['product_size_l'])
        wavyfin_w_list.append(instance['product_size_w'])
        wavyfin_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W1'):
        op10_l_list.append(instance['product_size_l'])
        op10_w_list.append(instance['product_size_w'])
        op10_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W1'):
        if instance['product_test'] == 'OK':
            op10_test_list.append(0)
        else:
            op10_test_list.append(1)
        
    if (instance['product_key'][27:] == 'pipe1'):
        pipe1_l_list.append(instance['product_size_l'])
        pipe1_w_list.append(instance['product_size_w'])
        pipe1_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W2'):
        op20_l_list.append(instance['product_size_l'])
        op20_w_list.append(instance['product_size_w'])
        op20_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W2'):
        if instance['product_test'] == 'OK':
            op20_test_list.append(0)
        else:
            op20_test_list.append(1)
        
    if (instance['product_key'][27:] == 'pipe2'):
        pipe2_l_list.append(instance['product_size_l'])
        pipe2_w_list.append(instance['product_size_w'])
        pipe2_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W3'):
        op30_l_list.append(instance['product_size_l'])
        op30_w_list.append(instance['product_size_w'])
        op30_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W3'):
        if instance['product_test'] == 'OK':
            op30_test_list.append(0)
        else:
            op30_test_list.append(1)
        
    if (instance['product_key'][27:] == 'flange1'):
        flange1_l_list.append(instance['product_size_l'])
        flange1_w_list.append(instance['product_size_w'])
        flange1_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W4'):
        op40_l_list.append(instance['product_size_l'])
        op40_w_list.append(instance['product_size_w'])
        op40_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W4'):
        if instance['product_test'] == 'OK':
            op40_test_list.append(0)
        else:
            op40_test_list.append(1)
        
    if (instance['product_key'][27:] == 'flange2'):
        flange2_l_list.append(instance['product_size_l'])
        flange2_w_list.append(instance['product_size_w'])
        flange2_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W5'):
        op50_l_list.append(instance['product_size_l'])
        op50_w_list.append(instance['product_size_w'])
        op50_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W5'):
        if instance['product_test'] == 'OK':
            op50_test_list.append(0)
        else:
            op50_test_list.append(1)
        
    if (instance['product_key'][27:29] == 'W6'):
        op60_l_list.append(instance['product_size_l'])
        op60_w_list.append(instance['product_size_w'])
        op60_h_list.append(instance['product_size_h'])
        
    if (instance['product_key'][27:29] == 'W6'):
        if instance['product_test'] == 'OK':
            op60_test_list.append(0)
        else:
            op60_test_list.append(1)
        
for instance in machine_data:
    
    if (instance['product_key'][27:29] == 'W1'):
        op10_electricity_list.append(instance['machine_data'])
        
    if (instance['product_key'][27:29] == 'W1'):
        op10_process_time_list.append(instance['process_time'])
        
    if (instance['product_key'][27:29] == 'W1'):
        op10_timestamp.append(instance['end_time'])
        
    if (instance['product_key'][27:29] == 'W2'):
        op20_electricity_list.append(instance['machine_data'])
        
    if (instance['product_key'][27:29] == 'W2'):
        op20_process_time_list.append(instance['process_time'])
        
    if (instance['product_key'][27:29] == 'W2'):
        op20_timestamp.append(instance['end_time'])
        
    if (instance['product_key'][27:29] == 'W3'):
        op30_electricity_list.append(instance['machine_data'])
        
    if (instance['product_key'][27:29] == 'W3'):
        op30_process_time_list.append(instance['process_time'])
        
    if (instance['product_key'][27:29] == 'W3'):
        op30_timestamp.append(instance['end_time'])
        
    if (instance['product_key'][27:29] == 'W4'):
        op40_temperature_list.append(instance['machine_data'])
        
    if (instance['product_key'][27:29] == 'W4'):
        op40_process_time_list.append(instance['process_time'])
        
    if (instance['product_key'][27:29] == 'W4'):
        op40_timestamp.append(instance['end_time'])
        
    if (instance['product_key'][27:29] == 'W5'):
        op50_temperature_list.append(instance['machine_data'])
        
    if (instance['product_key'][27:29] == 'W5'):
        op50_process_time_list.append(instance['process_time'])
        
    if (instance['product_key'][27:29] == 'W5'):
        op50_timestamp.append(instance['end_time'])
        
    if (instance['product_key'][27:29] == 'W6'):
        op60_process_time_list.append(instance['process_time'])
        
    if (instance['product_key'][27:29] == 'W6'):
        op60_timestamp.append(instance['end_time'])
        
df = pd.DataFrame({"product_key" : product_key_list, 'body_l' : body_l_list, 'body_w' : body_w_list, 'body_h' : body_h_list,
                   'wavyfin_l' : wavyfin_l_list, 'wavyfin_w' : wavyfin_w_list, 'wavyfin_h' : wavyfin_h_list,
                   'op10_l' : op10_l_list, 'op10_w' : op10_w_list, 'op10_h' : op10_h_list,
                   'op10_electricity' : op10_electricity_list, 'op10_process_time' : op10_process_time_list,
                   'op10_test' : op10_test_list, 'op10_timestamp' : op10_timestamp,
                   
                   'pipe1_l' : pipe1_l_list, 'pipe1_w' : pipe1_w_list, 'pipe1_h' : pipe1_h_list,
                   'op20_l' : op20_l_list, 'op20_w' : op20_w_list, 'op20_h' : op20_h_list,
                   'op20_electricity' : op20_electricity_list, 'op20_process_time' : op20_process_time_list,
                   'op20_test' : op20_test_list, 'op20_timestamp' : op20_timestamp,
                   
                   'pipe2_l' : pipe2_l_list, 'pipe2_w' : pipe2_w_list, 'pipe2_h' : pipe2_h_list,
                   'op30_l' : op30_l_list, 'op30_w' : op30_w_list, 'op30_h' : op30_h_list,
                   'op30_electricity' : op30_electricity_list, 'op30_process_time' : op30_process_time_list,
                   'op30_test' : op30_test_list, 'op30_timestamp' : op30_timestamp,
                   
                   'flange1' : flange1_l_list, 'flange1_w' : flange1_w_list, 'flange1_h' : flange1_h_list,
                   'op40_l' : op40_l_list, 'op40_w' : op40_w_list, 'op40_h' : op40_h_list,
                   'op40_temperature' : op40_temperature_list, 'op40_process_time' : op40_process_time_list,
                   'op40_test' : op40_test_list, 'op40_timestamp' : op40_timestamp,
                   
                   'flange2' : flange2_l_list, 'flange2_w' : flange2_w_list, 'flange2_h' : flange2_h_list,
                   'op50_l' : op50_l_list, 'op50_w' : op50_w_list, 'op50_h' : op50_h_list,
                   'op50_temperature' : op50_temperature_list, 'op50_process_time' : op50_process_time_list,
                   'op50_test' : op50_test_list, 'op50_timestamp' : op50_timestamp,
                   
                   'op60_l' : op60_l_list, 'op60_w' : op60_w_list, 'op60_h' : op60_h_list,
                   'op60_process_time' : op60_process_time_list, 
                   'op60_test' : op60_test_list, 'op60_timestamp' : op60_timestamp})

# %%
df
# Out:
#                        product_key   body_l    body_w   body_h  wavyfin_l  \
# 0  2020-10-31 16:39:04.376949-W6P0  200.001   99.9996  49.9983    99.9994
# 1  2020-10-31 16:39:14.642119-W6P1  199.999   99.9967  50.0004    99.9994
# 2  2020-10-31 16:39:24.709599-W6P2  199.999   99.9991  50.0002   100.0040
# 3  2020-10-31 16:39:33.261319-W6P3  199.999   99.9965  49.9978    99.9996
# 4  2020-10-31 16:39:44.534059-W6P4  199.999  100.0050  50.0025    99.9983
# 5  2020-10-31 16:39:54.014949-W6P5  200.000  100.0010  50.0013    99.9968
# 6  2020-10-31 16:40:02.884699-W6P6  199.999   99.9968  50.0019    99.9996
# 7  2020-10-31 16:40:13.331249-W6P7  199.999   99.9975  49.9977   100.0020
# 8  2020-10-31 16:40:22.232409-W6P8  199.996   99.9987  49.9980   100.0020
# 9  2020-10-31 16:40:33.021159-W6P9  200.003  100.0030  49.9963    99.9982
#
#    wavyfin_w  wavyfin_h   op10_l    op10_w   op10_h  ...  op50_temperature  \
# 0    49.9968    60.0001  200.001   99.9996  60.0001  ...           508.294
# 1    50.0027    60.0057  199.999   99.9967  60.0057  ...           510.700
# 2    50.0012    60.0035  199.999   99.9991  60.0035  ...           502.674
# 3    50.0007    60.0007  199.999   99.9965  60.0007  ...           508.166
# 4    50.0028    60.0012  199.999  100.0050  60.0012  ...           501.293
# 5    50.0010    59.9995  200.000  100.0010  59.9995  ...           492.091
# 6    50.0019    60.0036  199.999   99.9968  60.0036  ...           490.553
# 7    49.9978    60.0049  199.999   99.9975  60.0049  ...           504.986
# 8    49.9977    59.9996  199.996   99.9987  59.9996  ...           507.962
# 9    49.9984    59.9978  200.003  100.0030  59.9978  ...           501.646
#
#    op50_process_time  op50_test      op50_timestamp   op60_l   op60_w  \
# 0            9.10997          0 2020-10-31 16:38:55  259.997  179.998
# 1            9.53136          0 2020-10-31 16:39:05  259.997  179.995
# 2            9.98043          0 2020-10-31 16:39:15  259.996  179.994
# 3            9.29674          0 2020-10-31 16:39:24  259.996  179.997
# 4            9.97032          0 2020-10-31 16:39:35  260.003  180.008
# 5            9.83224          0 2020-10-31 16:39:45  259.999  180.002
# 6            9.76691          0 2020-10-31 16:39:53  259.998  179.998
# 7            9.84399          0 2020-10-31 16:40:04  259.997  179.998
# 8            9.51374          0 2020-10-31 16:40:13  259.995  179.999
# 9            9.29291          1 2020-10-31 16:40:23  259.997  180.151
#
#     op60_h  op60_process_time  op60_test      op60_timestamp
# 0  60.0001            9.67996          0 2020-10-31 16:39:04
# 1  60.0057            9.72926          0 2020-10-31 16:39:15
# 2  60.0035            9.88122          0 2020-10-31 16:39:25
# 3  60.0007            9.30522          0 2020-10-31 16:39:33
# 4  60.0012            9.73550          0 2020-10-31 16:39:45
# 5  59.9995            9.48987          0 2020-10-31 16:39:54
# 6  60.0036            9.41496          0 2020-10-31 16:40:03
# 7  60.0049            9.44266          0 2020-10-31 16:40:13
# 8  59.9996            9.04937          0 2020-10-31 16:40:22
# 9  59.9978            9.95942          1 2020-10-31 16:40:33
#
# [10 rows x 60 columns]

# %% [markdown]
# ## 부품 데이터로 양품 불량 예측 하기 (XGboost)

# %%
X_train = df.drop(['op60_timestamp', 'op60_process_time', 
                   'op60_h', 'op60_w', 'op60_l', 'op60_test', 
                   'op50_timestamp', 'op50_process_time', 
                   'op50_h', 'op50_w', 'op50_l', 'op50_temperature', 'op50_test',
                   'op40_timestamp', 'op40_process_time', 
                   'op40_h', 'op40_w', 'op40_l', 'op40_temperature', 'op40_test',
                   'op30_timestamp', 'op30_process_time', 
                   'op30_h', 'op30_w', 'op30_l', 'op30_electricity', 'op30_test',
                   'op20_timestamp', 'op20_process_time', 
                   'op20_h', 'op20_w', 'op20_l', 'op20_electricity', 'op20_test',
                   'op10_timestamp', 'op10_process_time', 
                   'op10_h', 'op10_w', 'op10_l', 'op10_electricity', 'op10_test',
                   'product_key'], axis = 1)
X_train.head()
# Out:
#     body_l    body_w   body_h  wavyfin_l  wavyfin_w  wavyfin_h  pipe1_l  \
# 0  200.001   99.9996  49.9983    99.9994    49.9968    60.0001  29.9990
# 1  199.999   99.9967  50.0004    99.9994    50.0027    60.0057  30.0047
# 2  199.999   99.9991  50.0002   100.0040    50.0012    60.0035  30.0033
# 3  199.999   99.9965  49.9978    99.9996    50.0007    60.0007  30.0026
# 4  199.999  100.0050  50.0025    99.9983    50.0028    60.0012  29.9999
#
#    pipe1_w  pipe1_h  pipe2_l  pipe2_w  pipe2_h  flange1  flange1_w  flange1_h  \
# 0  49.9981  30.0007  29.9949  50.0008  30.0014  29.9945    80.0050    39.9989
# 1  50.0005  29.9994  29.9978  49.9976  30.0030  29.9996    79.9997    40.0001
# 2  49.9968  29.9987  29.9971  49.9978  30.0020  29.9961    80.0058    40.0014
# 3  49.9999  30.0024  29.9989  50.0010  29.9991  29.9973    79.9949    40.0008
# 4  50.0046  30.0037  30.0022  49.9988  30.0051  29.9993    80.0016    39.9985
#
#    flange2  flange2_w  flange2_h
# 0  30.0018    80.0032    39.9973
# 1  29.9978    79.9976    39.9996
# 2  30.0011    79.9972    40.0037
# 3  30.0002    79.9991    39.9979
# 4  30.0040    80.0012    39.9984

# %%
y = df['op60_test']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: op60_test, dtype: int64

# %%
X = df.drop(['op60_timestamp', 'op60_process_time', 
                   'op60_h', 'op60_w', 'op60_l', 'op60_test', 
                   'op50_timestamp', 'op50_process_time', 
                   'op50_h', 'op50_w', 'op50_l', 'op50_temperature', 'op50_test',
                   'op40_timestamp', 'op40_process_time', 
                   'op40_h', 'op40_w', 'op40_l', 'op40_temperature', 'op40_test',
                   'op30_timestamp', 'op30_process_time', 
                   'op30_h', 'op30_w', 'op30_l', 'op30_electricity', 'op30_test',
                   'op20_timestamp', 'op20_process_time', 
                   'op20_h', 'op20_w', 'op20_l', 'op20_electricity', 'op20_test',
                   'op10_timestamp', 'op10_process_time', 
                   'op10_h', 'op10_w', 'op10_l', 'op10_electricity', 'op10_test',
                   'product_key'], axis = 1)
X_test.head()
# Out:
#     body_l    body_w   body_h  wavyfin_l  wavyfin_w  wavyfin_h  pipe1_l  \
# 0  200.001   99.9996  49.9983    99.9994    49.9968    60.0001  29.9990
# 1  199.999   99.9967  50.0004    99.9994    50.0027    60.0057  30.0047
# 2  199.999   99.9991  50.0002   100.0040    50.0012    60.0035  30.0033
# 3  199.999   99.9965  49.9978    99.9996    50.0007    60.0007  30.0026
# 4  199.999  100.0050  50.0025    99.9983    50.0028    60.0012  29.9999
#
#    pipe1_w  pipe1_h  pipe2_l  pipe2_w  pipe2_h  flange1  flange1_w  flange1_h  \
# 0  49.9981  30.0007  29.9949  50.0008  30.0014  29.9945    80.0050    39.9989
# 1  50.0005  29.9994  29.9978  49.9976  30.0030  29.9996    79.9997    40.0001
# 2  49.9968  29.9987  29.9971  49.9978  30.0020  29.9961    80.0058    40.0014
# 3  49.9999  30.0024  29.9989  50.0010  29.9991  29.9973    79.9949    40.0008
# 4  50.0046  30.0037  30.0022  49.9988  30.0051  29.9993    80.0016    39.9985
#
#    flange2  flange2_w  flange2_h
# 0  30.0018    80.0032    39.9973
# 1  29.9978    79.9976    39.9996
# 2  30.0011    79.9972    40.0037
# 3  30.0002    79.9991    39.9979
# 4  30.0040    80.0012    39.9984

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y, 
                                                    test_size=0.2, 
                                                    shuffle=False, 
                                                    random_state=1004)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8, 18)
# (2, 18)
# (8,)
# (2,)
